# %% [markdown]
# # Lab 4: Building a Spotify Song Classifier with KNNs and Decision Trees
# **Classify by genres**. In this lab, you will build machine learning genre classifiers using a dataset of Spotify tracks. Your goal is to train a model that can distinguish between two selected genres based on various audio features such as danceability, energy, valence, tempo, and more.
#
# We'll follow the familiar workflow of data exploration -> preprocessing -> model training -> evaluation

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Step 1: The data
# We'll focus on two genres: Blues and Jazz (what’s the difference, anyway??).
#
# Both genres have rich musical histories, but they differ in structure:
#
# - Blues tends to have simpler chord progressions and a strong emotional expression.
# - Jazz often involves complex improvisation and more varied rhythms.
#
# But can a machine really tell them apart just by looking at numerical audio features? That’s what we’ll find out!
#
# In this step, you will:
# - Load the dataset
# - Extract only blues and jazz for classification

# %%
spotify_data = pd.read_csv('/courses/EDS232/Data/spotify_dat.csv')
spotify_data.head()
spotify_data['genres'].unique()
# Out:
# array(['rap metal', 'soft rock', 'Unknown', 'singer-songwriter',
#        'americana', 'christian rock', 'skate punk', 'pop punk',
#        'new wave', 'country', 'madchester', 'j-rock', 'blues', 'grime',
#        'art rock', 'blues rock', 'chamber pop', 'french jazz', 'worship',
#        'ccm', 'alternative rock', 'indie rock', 'new age', 'classic rock',
#        'bluegrass', 'traditional country', 'classical piano', 'folk',
#        'chamber music', 'classical', 'minimalism', 'southern rock',
#        'roots rock', 'mariachi', 'nu jazz', 'breakcore', 'avant-garde',
#        'arabic rap', 'grunge', 'progressive rock', 'punk',
#        'post-hardcore', 'noise rock', 'sludge metal', 'nu metal', 'metal',
#        'industrial metal', 'hardcore', 'orchestra', 'latin jazz',
#        'dream pop', 'garage rock', 'trip hop', 'post-grunge', 'britpop',
#        'big beat', 'idm', 'rock en español', 'mexican ska',
#        'minimal techno', 'chanson', 'alternative dance', 'drone',
#        'proto-punk', 'gospel', 'indie folk', 'hardcore punk',
#        'neue deutsche welle', 'space music', 'r&b', 'latin pop',
#        'christmas', 'emo', 'power pop', 'chillstep', 'salsa',
#        'spoken word', 'west coast hip hop', 'christian', 'jangle pop',
#        'alt country', 'power metal', 'krautrock', 'industrial',
#        'melodic hardcore', 'hard techno', 'anime', 'bossa nova',
#        'vocal jazz', 'dark cabaret', 'southern hip hop', 'space rock',
#        'bebop', 'post-rock', 'glitch', 'doo-wop', 'celtic', 'cloud rap',
#        'cedm', 'speed metal', 'deathcore', 'flamenco', 'timba',
#        'breakbeat', 'folk rock', 'gothic country', 'soundtrack',
#        'metalcore', 'east coast hip hop', 'acid techno', 'dembow',
#        'free jazz', 'neoclassical', 'math rock', 'ambient', 'trap',
#        'nerdcore', 'v-pop', 'spanish language reggae',
#        'melodic death metal', 'j-pop', 'downtempo', 'reggae', 'jazz funk',
#        'country rock', 'future bass', 'medieval', 'soca', 'glam metal',
#        'heavy metal', 'boom bap', 'neofolk', 'opera', 'industrial rock',
#        'hi-nrg', 'symphonic rock', 'progressive metal', 'album rock',
#        'folk punk', 'psychedelic rock', 'shoegaze', 'nederpop', 'ragtime',
#        'slowcore', 'lo-fi beats', 'melodic bass', 'eurodance', 'mpb',
#        'afrobeat', 'drum and bass', 'afropop', 'motown', 'exotica',
#        'choral', 'neo soul', 'musicals', 'dark trap', 'happy hardcore',
#        'melodic rap', 'northern soul', 'boogie-woogie', 'shibuya-kei',
#        'hardcore techno', 'dubstep', 'alternative hip hop',
#        'variété française', 'schlager', 'trova', 'disco house',
#        'indie dance', 'deathrock', 'jazz rap', 'midwest emo',
#        'electroclash', 'rock', 'acid jazz', 'synthpop',
#        'underground hip hop', 'cantopop', 'comedy', 'ska', 'smooth jazz',
#        'swing music', 'christian folk', 'funk rock', 'symphonic metal',
#        'alternative pop', 'black metal', 'dark ambient', 'bolero',
#        'hard bop', 'ska punk', 'italo disco', 'latin alternative',
#        'hip house', 'post-punk', 'new jack swing', 'psychedelic pop',
#        'arena rock', 'acid house', 'gospel r&b', 'opm', 'soul', 'ebm',
#        'big band', 'groove metal', 'pop', 'experimental hip hop',
#        'darkwave', 'gothic metal', 'gangster rap', 'jazz fusion', 'sufi',
#        'rockabilly', 'christian alternative rock', 'red dirt',
#        'japanese vgm', 'iskelmä', 'rocksteady', 'requiem', 'tango',
#        'soul jazz', 'sea shanties', 'surf rock', 'traditional music',
#        'dansband', 'stoner rock', 'screamo', 'quiet storm', 'g-funk',
#        'horrorcore', 'art pop', 'alternative r&b', 'death metal',
#        'thai rock', 'melodic techno', 'jazz', 'dub techno', 'j-dance',
#        'miami bass', 'rhumba', 'bass music', 'italo dance',
#        'tropical house', 'brazilian rock', 'grindcore', 'experimental',
#        'lovers rock', 'alternative metal', 'nu disco', 'jungle',
#        'indietronica', 'thrash metal', 'liquid funk', 'drumstep',
#        'norteño', 'hands up', 'ranchera', 'freestyle', 'philly soul',
#        'chicago house', 'disco', 'funk melody', 'finnish rock',
#        'lo-fi house', 'psytrance', 'modern blues', 'champeta',
#        'funky house', 'latin house', 'deep house', 'uk garage',
#        'tech house', 'afro house', 'lounge', 'hard house', 'indie pop',
#        'psychobilly', 'swedish ballads', 'lo-fi', 'dub', 'folk pop',
#        'acoustic folk', 'europop', 'newgrass', 'country blues',
#        'honky tonk', "children's music", 'k-ballad', 'kundiman',
#        'tribal house', 'gregorian chant', 'reggae rock',
#        'vietnamese bolero', 'folk metal', 'medieval metal',
#        'pirate metal', 'french pop', 'merengue', 'classic blues',
#        'jazz blues', 'german pop', 'hard rock', 'mizrahi', 'glam rock',
#        'baroque pop', 'doom metal', 'new beat', 'dansktop',
#        'brazilian jazz', 'post-disco', 'rap', 'soft pop', 'gnawa',
#        'christian country', 'cold wave', 'chillwave', 'j-rap', 'latin',
#        'bassline', 'djent', 'soul blues', 'edm', 'acid rock',
#        'witch house', 'texas country', 'emocore', 'christian hip hop',
#        'canzone napoletana', 'adult standards', 'hyphy', 'synthwave',
#        'rap rock', 'axé', 'mexican hip hop', 'reggaeton', 'lullaby',
#        'disco polo', 'new rave', 'roots reggae', 'mandopop', 'techno',
#        'french house', 'indie jazz', 'trance', 'polka', 'rock urbano',
#        'hyperpop', 'riddim', 'italian singer-songwriter',
#        'japanese classical', 'acoustic pop', 'big room', 'visual kei',
#        'finnish pop', 'urbano latino', 'memphis rap', 'argentine rock',
#        'modern rock', 'indian indie', 'crunk', 'celtic rock',
#        'german hip hop', 'hardstyle', 'son cubano', 'deathstep', 'gabber',
#        'emo pop', 'progressive trance', 'piano house',
#        'brazilian hip hop', 'southern gospel', 'turkish pop', 'go-go',
#        'bachata', 'speedcore', 'turkish hip hop', 'slap house',
#        'latin folk', 'russelåter', 'latin hip hop', 'tekno', 'pinoy rock',
#        'bubblegum pop', 'eurotrance', 'hip hop', 'pagode', 'cool jazz',
#        'electro swing', 'dancehall', 'tejano', 'thai hip hop',
#        'country hip hop', 'k-pop', 'ragga', 'progressive house',
#        'uk funky', 'electronic rock', 'bhajan', 'devotional', 'bhangra',
#        'acoustic country', 'japanese indie', 'melodic metal',
#        'taiwanese pop', 'vaporwave', 'retro soul', 'brooklyn drill',
#        'meme rap', 'cha cha cha', 'taiwanese indie', 'funk', 'latin rock',
#        'kuduro', 'gengetone', 'grupera', 'calypso', 'indorock', 'mambo',
#        'tollywood', 'acoustic rock', 'norwegian rap', 'norwegian pop',
#        'chinese hip hop', 'kayokyoku', 'emo rap', 'nueva trova',
#        'salsa romantica', 'chicha', 'ethiopian jazz', 'música mexicana',
#        'banda', 'highlife', 'hiplife', 'zouk', 'brazilian bass',
#        'organic house', 'arabesque', 'malayalam pop', 'manele',
#        'latin r&b', 'anatolian rock', 'chinese rock', 'k-rap', 'epadunk',
#        'sertanejo', 'melbourne bounce', 'nz reggae', 'house',
#        'chill house', 'dance pop', 'smooth soul', 'folklore argentino',
#        'bedroom pop', 'moombahton', 'k-rock', 'pop rock', 'vocaloid',
#        'forró', 'raï', 'electropop', 'frenchcore', 'sovietwave',
#        'rage rap', 'pop urbaine', 'bass house', 'j-r&b', 'samba',
#        'qawwali', 'mexican rock', 'funk pop', 'malay pop',
#        'hardcore hip hop', 'afrobeats', 'edm trap', 'drill',
#        'brazilian pop', 'tamil dance', 'mexican indie', 'duranguense',
#        'piseiro', 'city pop', 'electro house', 'afro soul', 'ghazal',
#        'future house', 'funkot', 'egyptian pop', 'khaleeji', 'brega',
#        'brega funk', 'huayno', 'melodic house', 'sertanejo universitário',
#        'telugu pop', 'pop worship', 'uk drill', 'indonesian pop',
#        'portuguese hip hop', 'azonto', 'luk thung', 'afroswing',
#        'latin indie', 'fújì', 'bongo flava', 'nova mpb', 'malaysian pop',
#        'african gospel', 'indie', 'enka', 'pinoy indie', 'schlagerparty',
#        'malay', 'punto guajiro', 'fado', 'budots', 'algerian chaabi',
#        'latin dance', 'entehno', 'aussie drill', 'punk rap',
#        'hindi indie', 'desi pop', 'mahraganat', 'pinoy hip hop',
#        'pop country', 'stutter house', 'bounce', 'kizomba',
#        'easy listening', 'phleng phuea chiwit', 'tamil hip hop',
#        'singeli', 'latin afrobeat', 'vallenato', 'trap latino',
#        'electronic', 'finnish hip hop', 'jersey club', 'electro',
#        'brazilian evangelical music', 'amapiano', 'bangla pop',
#        'forro tradicional', 'chinese indie', 'indonesian indie',
#        'jazz beats', 'g-house', 'laïko', 'gufeng', 'tamil pop',
#        'rock and roll', 'vietnamese lo-fi', 'pop soul', 'gqom', 'seresta',
#        'bachata pop', 'bisrock', 'cumbia sonidera', 'c-pop',
#        'colombian pop', 'cumbia', 'boogie', 'p-pop', 'desi hip hop',
#        'punta', 'dangdut', 'sholawat', 'cuarteto', 'música tropical',
#        'punjabi hip hop', 'alté', 'neomelodico', 'mollywood',
#        'moroccan chaabi', 'norteño-sax', 'sertanejo tradicional',
#        'christian pop', 'karadeniz folk', 'oyun havasi', 'bhojpuri pop',
#        'desi', 'flamenco pop', 'pentecostal', 'pop rap', 'malay rap',
#        'phonk', 'pop r&b', 'indie r&b', 'bollywood', 'cumbia norteña',
#        'brazilian funk', 'pop urbano', 'corrido', 'malayalam hip hop',
#        'punjabi pop', 'chilean trap', 'batak', 'neoperreo', 'anime rap',
#        'sierreño', 'tamil indie', 'vietnam indie', 'kannada pop',
#        'reggaeton mexa', 'italian trap', 'maluku', 'electronica',
#        'reggaeton chileno', 'sandalwood', 'chilean mambo', 'pinoy r&b',
#        'funk consciente', 'nightcore', 'chinese r&b', 'funk de bh',
#        'thai indie pop', 'gujarati garba', 'popular colombian music',
#        'argentine trap', 'drift phonk', 'rave', 'marathi pop',
#        'trap funk', 'vinahouse', 'electro corridos', 'new york drill',
#        'egyptian hip hop', 'guaracha', 'sad sierreño', 'chill beats',
#        'brazilian trap', 'asakaa', 'corridos tumbados'], dtype=object)

# %%
spotify_data = pd.read_csv('/courses/EDS232/Data/spotify_dat.csv')
spotify_data.head()

# Print the data types in spotify_data
print(spotify_data.dtypes)

# Filter down to two genres
blues_data = spotify_data[spotify_data['genres'] == 'blues']
jazz_data =  spotify_data[spotify_data['genres'] == 'jazz']

# Combine both genres into one dataset
combined_data = pd.concat([jazz_data, blues_data])

# Rename 'genres' column to 'genre' for clarity
combined_data = combined_data.rename(columns={'genres': 'genre'})
combined_data.columns
# Out:
# id                   object
# name                 object
# album                object
# album_id             object
# artists              object
# artist_ids           object
# track_number          int64
# disc_number           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature      float64
# year                  int64
# release_date         object
# genres               object
# dtype: object
# Index(['id', 'name', 'album', 'album_id', 'artists', 'artist_ids',
#        'track_number', 'disc_number', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'year', 'release_date', 'genre'],
#       dtype='object')

# %% [markdown]
# ## Step 2: Data Exploration
# Now that we have Blues and Jazz as our two genres, it's time to explore the data and look for patterns in the audio features.
#
# Let's investigate:
# - Which features are available?
# - How strongly these features correlate with each other.
# - How different genres distribute across  sample features: danceability
#
# In this step, we will:
# - Filter out non-numeric columns before the plotting
# - Visualize feature correlations using a heatmap.
# - Examine key feature distributions with histograms to see if genres behave differently.

# %%
# Exclude non-numeric columns but keep 'genre' for grouping
numeric_features = combined_data.select_dtypes(['number'])
numeric_features['genre'] = combined_data.loc[:,'genre'].copy()

numeric_features.head()

plt.figure(figsize = (10, 8))

#Correlation heatmap
corr = numeric_features.select_dtypes('number').corr()

sns.heatmap(corr, annot =True)
# Out:
# /opt/python/3.7.13/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <AxesSubplot:>

# %% [markdown]
# ### Step 3: Check for class imbalance
# An unequal distribution between the target classes can cause issues for our classifiers, so we'll need to check for that. A commonly used guideline for class imbalance is:
#
# - Slight Imbalance (Less than 1.5:1) → Generally okay; no need for balancing.
# - Moderate Imbalance (Between 1.5:1 and 3:1) → Might cause some bias; balancing can help.
# - Severe Imbalance (More than 3:1) → Strongly affects model performance; balancing is usually necessary.

# %%
# Print counts of each genre
class_counts = 

# Calculate ratio of majority to minority class
class_ratio = 

# Print class distribution and ratio

# %% [markdown]
# Given this result, should we be worried about the imbalance?

# %% [markdown]
# *your answer here*

# %% [markdown]
# ### Step 4: Preprocessing
# We need to ensure all the variables we use are numerical so the models can process them. First we'll drop all the variables that are not numeric or the target. Then we'll use a sklearn utility, `LabelEncoder()` to encode our categorical target variable into numerical values. Print the first five values of your encoded labels.

# %%
# Define the features (drop columns that are not numeric or target)
X = 

# Set the target variable as 'genre'
y =  

# Encode the target variable ('label') using label encoding
label_encoder = 
y_encoded =

# Print first five values of encoded labels

# %% [markdown]
# Good, now we'll do our data splitting and scaling.  Let's go with an 80/20 split this time.

# %%
# Split data into 80% train and 20% test
X_train, X_test, y_train, y_test = 

# Initialize the scaler
scaler = 

# Fit and transform only the training set
X_train_scaled = 

# Use the same scaler to transform the test set
X_test_scaled =

# %% [markdown]
# ### Step 5: Train the models
# OK, now it's time to build our models and assess the training accuracy. We'll use the default of k = 5 for the KNN model.

# %%
# Initialize models
knn = 
dt = 

# Train (fit) both models


# Predictions on training data
knn_y_train_pred = 
dt_y_train_pred = 

# Compute training accuracy
knn_train_accuracy = 
dt_train_accuracy = 

#Print training accuracy for both models

# %% [markdown]
# ### Step 6: Evaluate models
# OK, now let's go ahead and predict on the test data to see how well our models do at predicting the genre of unseen tracks.

# %%
# Make predictions
knn_pred = 
dt_pred = 

# Evaluate prediction accuracy
knn_accuracy = 
dt_accuracy = 

#Print prediction accuracy for both models

# %% [markdown]
# ### Step 7: Visualizing Model Performance
# Now that we have evaluated our models on unseen data, let’s compare their performance by visualizing the training vs. test accuracy.  We'll look for signs of overfitting by plotting the training accuracy and test accuracy for both k-NN and Decision Trees.
#
# Create a bar chart that compares the training accuracy and test accuracy for k-NN and Decision Trees. Your plot should clearly display:
#
# - The training and test accuracy for both models.
# - Properly labeled axes and a title.
# - A legend to differentiate training and test accuracy.
# - Accuracy values displayed on top of each bar.

# %% [markdown]
# Which model does a better job of generalizing to unseen data? How do you know?
# Does it appear that either of the models are overfitting? Why?

# %% [markdown]
# *your anwer here*

# %% [markdown]
# ### Bonus question
# In the workflow above, we used the default parameter values of k = 5 for the KNN model, and maxdepth = None for the Decision Tree. Choose one of the models and see if you can improve test performance by optmizing its corresponding parameter value.
