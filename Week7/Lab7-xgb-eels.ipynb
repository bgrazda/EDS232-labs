# %% [markdown]
# ## Lab 7: Eel Distribution Modeling with XGBoost
#
# **Reference Paper:** [Elith et al. (2008)](https://ucsb.box.com/s/6k7636wsbogdg3orarxrlowke0ounbic)
#
# In this lab, you will model the distribution of the eel species *Anguilla australis* using **boosted classification trees (BCTs)**, a machine learning technique that improves predictive performance by combining multiple decision trees. Elith et al. (2008) offered an early implementation of BRTs in an ecological setting to understand how environmental variables influence eel distribution.
#
# You will work with **two datasets**:
# 1. **Training Data** – Used to build and evaluate your XGBoost model.
# 2. **Evaluation Data** – Used to assess model performance on unseen data.
#
# To achieve the following objectives:
# - Train and fine-tune an **XGBoost** model for classification of species presence/absence data.
# - Compare your model’s performance to the approach used by Elith et al.
#
#
# **Wherever applicable in this lab, use a random state of 808.**

# %% [markdown]
# ### Step 0: Load libraries and data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from scipy.stats import uniform, randint

# Download the datasets
model_data = pd.read_csv("/courses/EDS232/Data/model.data.csv").drop(columns=['Site'])
eval_data = pd.read_csv("/courses/EDS232/Data/eval.data.csv")

# %% [markdown]
# ### Step 1:Initial Data Preprocessing
# Let's get started by preparing our data. `Angaus` will be our target variable(`y`), and all other variables will be our features (`X`). Then encode the categorical feature using `LabelEncoder()`. The final step will be a bit different this time.  We don't need to split off testing data for the final model evaluation; a separate set (`eval_data`) will be used as in Elith et al.  We do, however, need to split our data in order to do the early stopping process. When splitting your data into training and validation, use a test size of 0.2 and a random state of 808.

# %%
# Features from df
y = model_data['Angaus']
X = model_data.drop('Angaus', axis = 1)

#Initialize label encoder
le = LabelEncoder()
X['Method'] = le.fit_transform(X['Method'])

# Split into training and validation data
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 808)

# %% [markdown]
# ### Step 2: Determine best number of trees using early stopping
# As a guard against overfitting while maximizing performance, we use **early stopping**. We start with a large number of trees and allow XGBoost to determine the optimal number by stopping training when the validation error no longer improves.
#
# The choice of hyperparameter starting values is important in this process. We begin with:
# - `n_estimators=1000` to ensure the model has enough capacity to learn meaningful patterns.
# - `learning_rate=0.1` as a reasonable default that balances learning speed and performance.
# - `eval_metric="logloss"` as the metric of performance to optimize.
# - `early_stopping_rounds=50` to halt training if no improvement is seen for 50 rounds, preventing unnecessary computations.
# - `random_state = 808`
#
# We then `fit()` our specified baseline model, passing in the training sets as usual and specifying validation sets values for the `eval_set` parameter.
#
# Finally, get and print the best number of trees from the fitted baseline model.

# %%
# Initialize XGB model
xgb = XGBClassifier(
    n_estimators=1000,
    learning_rate=0.1, 
    early_stopping_rounds=50, 
    eval_metric="logloss", 
    random_state=808)

# Fit model
xgb.fit(X_train, y_train, eval_set=[(X_val, y_val)])
# Out:
# [0]	validation_0-logloss:0.64173
# [1]	validation_0-logloss:0.59874
# [2]	validation_0-logloss:0.56352
# [3]	validation_0-logloss:0.53716
# [4]	validation_0-logloss:0.51702
# [5]	validation_0-logloss:0.50016
# [6]	validation_0-logloss:0.48135
# [7]	validation_0-logloss:0.46672
# [8]	validation_0-logloss:0.45634
# [9]	validation_0-logloss:0.44405
# [10]	validation_0-logloss:0.43728
# [11]	validation_0-logloss:0.42904
# [12]	validation_0-logloss:0.41955
# [13]	validation_0-logloss:0.41371
# [14]	validation_0-logloss:0.40708
# [15]	validation_0-logloss:0.40332
# [16]	validation_0-logloss:0.39853
# [17]	validation_0-logloss:0.39618
# [18]	validation_0-logloss:0.39130
# [19]	validation_0-logloss:0.38952
# [20]	validation_0-logloss:0.38569
# [21]	validation_0-logloss:0.38372
# [22]	validation_0-logloss:0.37811
# [23]	validation_0-logloss:0.37809
# [24]	validation_0-logloss:0.37631
# [25]	validation_0-logloss:0.37448
# [26]	validation_0-logloss:0.37215
# [27]	validation_0-logloss:0.37295
# [28]	validation_0-logloss:0.37361
# [29]	validation_0-logloss:0.37298
# [30]	validation_0-logloss:0.37111
# [31]	validation_0-logloss:0.36678
# [32]	validation_0-logloss:0.36474
# [33]	validation_0-logloss:0.36441
# [34]	validation_0-logloss:0.36178
# [35]	validation_0-logloss:0.36257
# [36]	validation_0-logloss:0.36204
# [37]	validation_0-logloss:0.36236
# [38]	validation_0-logloss:0.36360
# [39]	validation_0-logloss:0.36289
# [40]	validation_0-logloss:0.36378
# [41]	validation_0-logloss:0.36328
# [42]	validation_0-logloss:0.36317
# [43]	validation_0-logloss:0.36350
# [44]	validation_0-logloss:0.36341
# [45]	validation_0-logloss:0.36350
# [46]	validation_0-logloss:0.36414
# [47]	validation_0-logloss:0.36552
# [48]	validation_0-logloss:0.36637
# [49]	validation_0-logloss:0.36420
# [50]	validation_0-logloss:0.36479
# [51]	validation_0-logloss:0.36663
# [52]	validation_0-logloss:0.36640
# [53]	validation_0-logloss:0.36630
# [54]	validation_0-logloss:0.36706
# [55]	validation_0-logloss:0.36776
# [56]	validation_0-logloss:0.36805
# [57]	validation_0-logloss:0.36718
# [58]	validation_0-logloss:0.36727
# [59]	validation_0-logloss:0.36867
# [60]	validation_0-logloss:0.36933
# [61]	validation_0-logloss:0.36911
# [62]	validation_0-logloss:0.36886
# [63]	validation_0-logloss:0.36849
# [64]	validation_0-logloss:0.36910
# [65]	validation_0-logloss:0.36992
# [66]	validation_0-logloss:0.36991
# [67]	validation_0-logloss:0.37017
# [68]	validation_0-logloss:0.37117
# [69]	validation_0-logloss:0.37183
# [70]	validation_0-logloss:0.37184
# [71]	validation_0-logloss:0.37326
# [72]	validation_0-logloss:0.37371
# [73]	validation_0-logloss:0.37386
# [74]	validation_0-logloss:0.37340
# [75]	validation_0-logloss:0.37504
# [76]	validation_0-logloss:0.37641
# [77]	validation_0-logloss:0.37706
# [78]	validation_0-logloss:0.37773
# [79]	validation_0-logloss:0.37839
# [80]	validation_0-logloss:0.38038
# [81]	validation_0-logloss:0.38096
# [82]	validation_0-logloss:0.38221
# [83]	validation_0-logloss:0.38273
# [84]	validation_0-logloss:0.38356
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=50, enable_categorical=False,
#               eval_metric='logloss', gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_to_onehot=4, max_delta_step=0, max_depth=6, max_leaves=0,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=1000, n_jobs=0, num_parallel_tree=1,
#               predictor='auto', random_state=808, reg_alpha=0, reg_lambda=1, ...)

# %%
# Print best number of trees
best_ntrees = xgb.best_iteration
print(f"Best number of trees {best_ntrees}")
# Out:
# Best number of trees 34

# %% [markdown]
# ### Step 3: Tune Learning Rate
#
# The (`learning_rate` hyperparameter controls how much each tree contributes to improving the model's performance. A *higher* learning rate allows the model to learn quickly but risks missing the optimal solution and overfitting, while a *lower* learning rate makes learning slower but can improve generalization.
#
# To find the optimal value, we'll use **randomized search cross-validation** (`RandomizedSearchCV`) to test different learning rates in the 0.01 to 0.3 range. Instead of testing every possible value, this method samples a set number of candidates (`n_iter`) from a defined parameter distribution.  In this case, sampling 20 candidates from a uniform distribution between `0.01` and `0.31`. Check out the [documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.uniform.html) on `scipy.stats.uniform` to see how it differs from `random.uniform`. Be sure to use a random state of 808.
#
# After using `RandomizedSearchCV`, fit your model. Print the best learning rate.

# %%
# Initialize second XGB model
xgb2 = XGBClassifier(
    n_estimators=best_ntrees,
    learning_rate=0.1, 
    early_stopping_rounds=50, 
    eval_metric="logloss", 
    random_state=808)

# Fit model
xgb2.fit(X_train, y_train, eval_set=[(X_val, y_val)])

# Create a parameter distribution for learning rate
param_dist = {
    "learning_rate": uniform(0.01, 0.3), 
}

# Set up RandomizedSearchCV
rs = RandomizedSearchCV(
    xgb2, param_dist, n_iter=20, scoring='accuracy', 
    cv=3, verbose=False, random_state=808
)

# Run random search
rs.fit(X_train, y_train, eval_set=[(X_val, y_val)])
# Out:
# [0]	validation_0-logloss:0.64173
# [1]	validation_0-logloss:0.59874
# [2]	validation_0-logloss:0.56352
# [3]	validation_0-logloss:0.53716
# [4]	validation_0-logloss:0.51702
# [5]	validation_0-logloss:0.50016
# [6]	validation_0-logloss:0.48135
# [7]	validation_0-logloss:0.46672
# [8]	validation_0-logloss:0.45634
# [9]	validation_0-logloss:0.44405
# [10]	validation_0-logloss:0.43728
# [11]	validation_0-logloss:0.42904
# [12]	validation_0-logloss:0.41955
# [13]	validation_0-logloss:0.41371
# [14]	validation_0-logloss:0.40708
# [15]	validation_0-logloss:0.40332
# [16]	validation_0-logloss:0.39853
# [17]	validation_0-logloss:0.39618
# [18]	validation_0-logloss:0.39130
# [19]	validation_0-logloss:0.38952
# [20]	validation_0-logloss:0.38569
# [21]	validation_0-logloss:0.38372
# [22]	validation_0-logloss:0.37811
# [23]	validation_0-logloss:0.37809
# [24]	validation_0-logloss:0.37631
# [25]	validation_0-logloss:0.37448
# [26]	validation_0-logloss:0.37215
# [27]	validation_0-logloss:0.37295
# [28]	validation_0-logloss:0.37361
# [29]	validation_0-logloss:0.37298
# [30]	validation_0-logloss:0.37111
# [31]	validation_0-logloss:0.36678
# [32]	validation_0-logloss:0.36474
# [33]	validation_0-logloss:0.36441
# [0]	validation_0-logloss:0.56908
# [1]	validation_0-logloss:0.49891
# [2]	validation_0-logloss:0.45981
# [3]	validation_0-logloss:0.43604
# [4]	validation_0-logloss:0.42500
# [5]	validation_0-logloss:0.40899
# [6]	validation_0-logloss:0.40662
# [7]	validation_0-logloss:0.40909
# [8]	validation_0-logloss:0.40709
# [9]	validation_0-logloss:0.40840
# [10]	validation_0-logloss:0.41795
# [11]	validation_0-logloss:0.41934
# [12]	validation_0-logloss:0.42356
# [13]	validation_0-logloss:0.42124
# [14]	validation_0-logloss:0.41640
# [15]	validation_0-logloss:0.41413
# [16]	validation_0-logloss:0.42325
# [17]	validation_0-logloss:0.42369
# [18]	validation_0-logloss:0.42674
# [19]	validation_0-logloss:0.42404
# [20]	validation_0-logloss:0.42522
# [21]	validation_0-logloss:0.43016
# [22]	validation_0-logloss:0.42933
# [23]	validation_0-logloss:0.42682
# [24]	validation_0-logloss:0.42607
# [25]	validation_0-logloss:0.42918
# [26]	validation_0-logloss:0.43327
# [27]	validation_0-logloss:0.43696
# [28]	validation_0-logloss:0.44180
# [29]	validation_0-logloss:0.44985
# [30]	validation_0-logloss:0.44525
# [31]	validation_0-logloss:0.44391
# [32]	validation_0-logloss:0.44360
# [33]	validation_0-logloss:0.44265
# [0]	validation_0-logloss:0.55889
# [1]	validation_0-logloss:0.49660
# [2]	validation_0-logloss:0.44394
# [3]	validation_0-logloss:0.41520
# [4]	validation_0-logloss:0.39566
# [5]	validation_0-logloss:0.38482
# [6]	validation_0-logloss:0.37526
# [7]	validation_0-logloss:0.36791
# [8]	validation_0-logloss:0.36158
# [9]	validation_0-logloss:0.36274
# [10]	validation_0-logloss:0.36536
# [11]	validation_0-logloss:0.36226
# [12]	validation_0-logloss:0.36557
# [13]	validation_0-logloss:0.36955
# [14]	validation_0-logloss:0.36792
# [15]	validation_0-logloss:0.36796
# [16]	validation_0-logloss:0.37117
# [17]	validation_0-logloss:0.37565
# [18]	validation_0-logloss:0.37648
# [19]	validation_0-logloss:0.38720
# [20]	validation_0-logloss:0.38692
# [21]	validation_0-logloss:0.39613
# [22]	validation_0-logloss:0.39703
# [23]	validation_0-logloss:0.39960
# [24]	validation_0-logloss:0.40598
# [25]	validation_0-logloss:0.40738
# [26]	validation_0-logloss:0.40797
# [27]	validation_0-logloss:0.41058
# [28]	validation_0-logloss:0.41163
# [29]	validation_0-logloss:0.41821
# [30]	validation_0-logloss:0.42460
# [31]	validation_0-logloss:0.42788
# [32]	validation_0-logloss:0.42653
# [33]	validation_0-logloss:0.42622
# [0]	validation_0-logloss:0.57692
# [1]	validation_0-logloss:0.50906
# [2]	validation_0-logloss:0.46489
# [3]	validation_0-logloss:0.44335
# [4]	validation_0-logloss:0.42646
# [5]	validation_0-logloss:0.42153
# [6]	validation_0-logloss:0.41236
# [7]	validation_0-logloss:0.40946
# [8]	validation_0-logloss:0.41171
# [9]	validation_0-logloss:0.40729
# [10]	validation_0-logloss:0.41359
# [11]	validation_0-logloss:0.41155
# [12]	validation_0-logloss:0.41865
# [13]	validation_0-logloss:0.42184
# [14]	validation_0-logloss:0.42986
# [15]	validation_0-logloss:0.42815
# [16]	validation_0-logloss:0.42865
# [17]	validation_0-logloss:0.44176
# [18]	validation_0-logloss:0.44384
# [19]	validation_0-logloss:0.44622
# [20]	validation_0-logloss:0.44472
# [21]	validation_0-logloss:0.44405
# [22]	validation_0-logloss:0.43868
# [23]	validation_0-logloss:0.44331
# [24]	validation_0-logloss:0.45291
# [25]	validation_0-logloss:0.45690
# [26]	validation_0-logloss:0.45478
# [27]	validation_0-logloss:0.45563
# [28]	validation_0-logloss:0.45774
# [29]	validation_0-logloss:0.45528
# [30]	validation_0-logloss:0.46580
# [31]	validation_0-logloss:0.46778
# [32]	validation_0-logloss:0.46978
# [33]	validation_0-logloss:0.46895
# [0]	validation_0-logloss:0.65680
# [1]	validation_0-logloss:0.62340
# [2]	validation_0-logloss:0.59460
# [3]	validation_0-logloss:0.57369
# [4]	validation_0-logloss:0.55163
# [5]	validation_0-logloss:0.53382
# [6]	validation_0-logloss:0.51582
# [7]	validation_0-logloss:0.49939
# [8]	validation_0-logloss:0.48596
# [9]	validation_0-logloss:0.47408
# [10]	validation_0-logloss:0.46367
# [11]	validation_0-logloss:0.45499
# [12]	validation_0-logloss:0.44563
# [13]	validation_0-logloss:0.43880
# [14]	validation_0-logloss:0.43318
# [15]	validation_0-logloss:0.42691
# [16]	validation_0-logloss:0.41991
# [17]	validation_0-logloss:0.41818
# [18]	validation_0-logloss:0.41271
# [19]	validation_0-logloss:0.40857
# [20]	validation_0-logloss:0.40521
# [21]	validation_0-logloss:0.40285
# [22]	validation_0-logloss:0.39995
# [23]	validation_0-logloss:0.39795
# [24]	validation_0-logloss:0.39374
# [25]	validation_0-logloss:0.39133
# [26]	validation_0-logloss:0.38878
# [27]	validation_0-logloss:0.38641
# [28]	validation_0-logloss:0.38498
# [29]	validation_0-logloss:0.38479
# [30]	validation_0-logloss:0.38472
# [31]	validation_0-logloss:0.38349
# [32]	validation_0-logloss:0.38306
# [33]	validation_0-logloss:0.38208
# [0]	validation_0-logloss:0.65463
# [1]	validation_0-logloss:0.62336
# [2]	validation_0-logloss:0.59667
# [3]	validation_0-logloss:0.56992
# [4]	validation_0-logloss:0.55096
# [5]	validation_0-logloss:0.52991
# [6]	validation_0-logloss:0.51149
# [7]	validation_0-logloss:0.49535
# [8]	validation_0-logloss:0.48198
# [9]	validation_0-logloss:0.46927
# [10]	validation_0-logloss:0.45830
# [11]	validation_0-logloss:0.44775
# [12]	validation_0-logloss:0.44091
# [13]	validation_0-logloss:0.43208
# [14]	validation_0-logloss:0.42463
# [15]	validation_0-logloss:0.41886
# [16]	validation_0-logloss:0.41411
# [17]	validation_0-logloss:0.41027
# [18]	validation_0-logloss:0.40577
# [19]	validation_0-logloss:0.40217
# [20]	validation_0-logloss:0.39885
# [21]	validation_0-logloss:0.39631
# [22]	validation_0-logloss:0.39337
# [23]	validation_0-logloss:0.39053
# [24]	validation_0-logloss:0.38558
# [25]	validation_0-logloss:0.38306
# [26]	validation_0-logloss:0.37987
# [27]	validation_0-logloss:0.37868
# [28]	validation_0-logloss:0.37783
# [29]	validation_0-logloss:0.37560
# [30]	validation_0-logloss:0.37302
# [31]	validation_0-logloss:0.37278
# [32]	validation_0-logloss:0.37234
# [33]	validation_0-logloss:0.37227
# [0]	validation_0-logloss:0.65897
# [1]	validation_0-logloss:0.62870
# [2]	validation_0-logloss:0.60304
# [3]	validation_0-logloss:0.58051
# [4]	validation_0-logloss:0.55977
# [5]	validation_0-logloss:0.54314
# [6]	validation_0-logloss:0.52830
# [7]	validation_0-logloss:0.51496
# [8]	validation_0-logloss:0.50329
# [9]	validation_0-logloss:0.49288
# [10]	validation_0-logloss:0.48305
# [11]	validation_0-logloss:0.47380
# [12]	validation_0-logloss:0.46481
# [13]	validation_0-logloss:0.45667
# [14]	validation_0-logloss:0.44910
# [15]	validation_0-logloss:0.44111
# [16]	validation_0-logloss:0.43727
# [17]	validation_0-logloss:0.43231
# [18]	validation_0-logloss:0.42803
# [19]	validation_0-logloss:0.42464
# [20]	validation_0-logloss:0.42073
# [21]	validation_0-logloss:0.41757
# [22]	validation_0-logloss:0.41543
# [23]	validation_0-logloss:0.41262
# [24]	validation_0-logloss:0.41029
# [25]	validation_0-logloss:0.40737
# [26]	validation_0-logloss:0.40559
# [27]	validation_0-logloss:0.40316
# [28]	validation_0-logloss:0.40078
# [29]	validation_0-logloss:0.39867
# [30]	validation_0-logloss:0.39742
# [31]	validation_0-logloss:0.39649
# [32]	validation_0-logloss:0.39524
# [33]	validation_0-logloss:0.39573
# [0]	validation_0-logloss:0.67229
# [1]	validation_0-logloss:0.65380
# [2]	validation_0-logloss:0.63489
# [3]	validation_0-logloss:0.61806
# [4]	validation_0-logloss:0.60483
# [5]	validation_0-logloss:0.59017
# [6]	validation_0-logloss:0.57727
# [7]	validation_0-logloss:0.56449
# [8]	validation_0-logloss:0.55241
# [9]	validation_0-logloss:0.54057
# [10]	validation_0-logloss:0.53022
# [11]	validation_0-logloss:0.52027
# [12]	validation_0-logloss:0.51138
# [13]	validation_0-logloss:0.50283
# [14]	validation_0-logloss:0.49436
# [15]	validation_0-logloss:0.48701
# [16]	validation_0-logloss:0.48005
# [17]	validation_0-logloss:0.47539
# [18]	validation_0-logloss:0.46975
# [19]	validation_0-logloss:0.46462
# [20]	validation_0-logloss:0.45914
# [21]	validation_0-logloss:0.45545
# [22]	validation_0-logloss:0.45006
# [23]	validation_0-logloss:0.44611
# [24]	validation_0-logloss:0.44095
# [25]	validation_0-logloss:0.43710
# [26]	validation_0-logloss:0.43344
# [27]	validation_0-logloss:0.42914
# [28]	validation_0-logloss:0.42550
# [29]	validation_0-logloss:0.42173
# [30]	validation_0-logloss:0.41847
# [31]	validation_0-logloss:0.41500
# [32]	validation_0-logloss:0.41199
# [33]	validation_0-logloss:0.41004
# [0]	validation_0-logloss:0.67111
# [1]	validation_0-logloss:0.65193
# [2]	validation_0-logloss:0.63472
# [3]	validation_0-logloss:0.61765
# [4]	validation_0-logloss:0.60292
# [5]	validation_0-logloss:0.58818
# [6]	validation_0-logloss:0.57383
# [7]	validation_0-logloss:0.56066
# [8]	validation_0-logloss:0.55015
# [9]	validation_0-logloss:0.53804
# [10]	validation_0-logloss:0.52715
# [11]	validation_0-logloss:0.51668
# [12]	validation_0-logloss:0.50635
# [13]	validation_0-logloss:0.49778
# [14]	validation_0-logloss:0.48983
# [15]	validation_0-logloss:0.48093
# [16]	validation_0-logloss:0.47330
# [17]	validation_0-logloss:0.46713
# [18]	validation_0-logloss:0.46114
# [19]	validation_0-logloss:0.45474
# [20]	validation_0-logloss:0.44925
# [21]	validation_0-logloss:0.44386
# [22]	validation_0-logloss:0.43865
# [23]	validation_0-logloss:0.43334
# [24]	validation_0-logloss:0.42893
# [25]	validation_0-logloss:0.42499
# [26]	validation_0-logloss:0.42115
# [27]	validation_0-logloss:0.41780
# [28]	validation_0-logloss:0.41458
# [29]	validation_0-logloss:0.41157
# [30]	validation_0-logloss:0.40815
# [31]	validation_0-logloss:0.40585
# [32]	validation_0-logloss:0.40365
# [33]	validation_0-logloss:0.40174
# [0]	validation_0-logloss:0.67353
# [1]	validation_0-logloss:0.65496
# [2]	validation_0-logloss:0.63797
# [3]	validation_0-logloss:0.62280
# [4]	validation_0-logloss:0.60856
# [5]	validation_0-logloss:0.59485
# [6]	validation_0-logloss:0.58279
# [7]	validation_0-logloss:0.57153
# [8]	validation_0-logloss:0.56040
# [9]	validation_0-logloss:0.55076
# [10]	validation_0-logloss:0.54144
# [11]	validation_0-logloss:0.53303
# [12]	validation_0-logloss:0.52482
# [13]	validation_0-logloss:0.51728
# [14]	validation_0-logloss:0.51011
# [15]	validation_0-logloss:0.50279
# [16]	validation_0-logloss:0.49692
# [17]	validation_0-logloss:0.49154
# [18]	validation_0-logloss:0.48616
# [19]	validation_0-logloss:0.48131
# [20]	validation_0-logloss:0.47594
# [21]	validation_0-logloss:0.47174
# [22]	validation_0-logloss:0.46795
# [23]	validation_0-logloss:0.46337
# [24]	validation_0-logloss:0.45941
# [25]	validation_0-logloss:0.45496
# [26]	validation_0-logloss:0.45159
# [27]	validation_0-logloss:0.44799
# [28]	validation_0-logloss:0.44550
# [29]	validation_0-logloss:0.44180
# [30]	validation_0-logloss:0.43955
# [31]	validation_0-logloss:0.43705
# [32]	validation_0-logloss:0.43477
# [33]	validation_0-logloss:0.43184
# [0]	validation_0-logloss:0.61288
# [1]	validation_0-logloss:0.55222
# [2]	validation_0-logloss:0.51131
# [3]	validation_0-logloss:0.48080
# [4]	validation_0-logloss:0.46134
# [5]	validation_0-logloss:0.44351
# [6]	validation_0-logloss:0.42914
# [7]	validation_0-logloss:0.41477
# [8]	validation_0-logloss:0.40852
# [9]	validation_0-logloss:0.40505
# [10]	validation_0-logloss:0.39877
# [11]	validation_0-logloss:0.39811
# [12]	validation_0-logloss:0.38988
# [13]	validation_0-logloss:0.39087
# [14]	validation_0-logloss:0.39120
# [15]	validation_0-logloss:0.39183
# [16]	validation_0-logloss:0.39148
# [17]	validation_0-logloss:0.39336
# [18]	validation_0-logloss:0.39513
# [19]	validation_0-logloss:0.39269
# [20]	validation_0-logloss:0.39399
# [21]	validation_0-logloss:0.39496
# [22]	validation_0-logloss:0.39702
# [23]	validation_0-logloss:0.39933
# [24]	validation_0-logloss:0.40137
# [25]	validation_0-logloss:0.40025
# [26]	validation_0-logloss:0.39977
# [27]	validation_0-logloss:0.40137
# [28]	validation_0-logloss:0.40276
# [29]	validation_0-logloss:0.40389
# [30]	validation_0-logloss:0.40517
# [31]	validation_0-logloss:0.40581
# [32]	validation_0-logloss:0.40338
# [33]	validation_0-logloss:0.40360
# [0]	validation_0-logloss:0.60733
# [1]	validation_0-logloss:0.55308
# [2]	validation_0-logloss:0.50768
# [3]	validation_0-logloss:0.47418
# [4]	validation_0-logloss:0.44821
# [5]	validation_0-logloss:0.42888
# [6]	validation_0-logloss:0.41002
# [7]	validation_0-logloss:0.39962
# [8]	validation_0-logloss:0.39125
# [9]	validation_0-logloss:0.38032
# [10]	validation_0-logloss:0.37656
# [11]	validation_0-logloss:0.36966
# [12]	validation_0-logloss:0.36853
# [13]	validation_0-logloss:0.36808
# [14]	validation_0-logloss:0.37022
# [15]	validation_0-logloss:0.36748
# [16]	validation_0-logloss:0.36811
# [17]	validation_0-logloss:0.37309
# [18]	validation_0-logloss:0.37422
# [19]	validation_0-logloss:0.37778
# [20]	validation_0-logloss:0.37962
# [21]	validation_0-logloss:0.38116
# [22]	validation_0-logloss:0.38264
# [23]	validation_0-logloss:0.38559
# [24]	validation_0-logloss:0.38884
# [25]	validation_0-logloss:0.39090
# [26]	validation_0-logloss:0.39094
# [27]	validation_0-logloss:0.39047
# [28]	validation_0-logloss:0.39080
# [29]	validation_0-logloss:0.39174
# [30]	validation_0-logloss:0.39067
# [31]	validation_0-logloss:0.39060
# [32]	validation_0-logloss:0.39035
# [33]	validation_0-logloss:0.39219
# [0]	validation_0-logloss:0.61779
# [1]	validation_0-logloss:0.56175
# [2]	validation_0-logloss:0.52013
# [3]	validation_0-logloss:0.49611
# [4]	validation_0-logloss:0.47239
# [5]	validation_0-logloss:0.45536
# [6]	validation_0-logloss:0.44150
# [7]	validation_0-logloss:0.42909
# [8]	validation_0-logloss:0.41808
# [9]	validation_0-logloss:0.41104
# [10]	validation_0-logloss:0.40365
# [11]	validation_0-logloss:0.40265
# [12]	validation_0-logloss:0.40050
# [13]	validation_0-logloss:0.40108
# [14]	validation_0-logloss:0.39944
# [15]	validation_0-logloss:0.40105
# [16]	validation_0-logloss:0.39778
# [17]	validation_0-logloss:0.39779
# [18]	validation_0-logloss:0.40130
# [19]	validation_0-logloss:0.40370
# [20]	validation_0-logloss:0.40494
# [21]	validation_0-logloss:0.40921
# [22]	validation_0-logloss:0.41087
# [23]	validation_0-logloss:0.41327
# [24]	validation_0-logloss:0.41579
# [25]	validation_0-logloss:0.41821
# [26]	validation_0-logloss:0.41816
# [27]	validation_0-logloss:0.42081
# [28]	validation_0-logloss:0.42374
# [29]	validation_0-logloss:0.42334
# [30]	validation_0-logloss:0.42696
# [31]	validation_0-logloss:0.43192
# [32]	validation_0-logloss:0.43334
# [33]	validation_0-logloss:0.43491
# [0]	validation_0-logloss:0.59608
# [1]	validation_0-logloss:0.52905
# [2]	validation_0-logloss:0.48687
# [3]	validation_0-logloss:0.45639
# [4]	validation_0-logloss:0.43555
# [5]	validation_0-logloss:0.41378
# [6]	validation_0-logloss:0.39604
# [7]	validation_0-logloss:0.38815
# [8]	validation_0-logloss:0.38591
# [9]	validation_0-logloss:0.37964
# [10]	validation_0-logloss:0.37864
# [11]	validation_0-logloss:0.37471
# [12]	validation_0-logloss:0.37702
# [13]	validation_0-logloss:0.37131
# [14]	validation_0-logloss:0.37359
# [15]	validation_0-logloss:0.37721
# [16]	validation_0-logloss:0.38047
# [17]	validation_0-logloss:0.38538
# [18]	validation_0-logloss:0.38535
# [19]	validation_0-logloss:0.38257
# [20]	validation_0-logloss:0.38574
# [21]	validation_0-logloss:0.39121
# [22]	validation_0-logloss:0.39223
# [23]	validation_0-logloss:0.39074
# [24]	validation_0-logloss:0.39107
# [25]	validation_0-logloss:0.38986
# [26]	validation_0-logloss:0.38872
# [27]	validation_0-logloss:0.39150
# [28]	validation_0-logloss:0.39358
# [29]	validation_0-logloss:0.39779
# [30]	validation_0-logloss:0.40216
# [31]	validation_0-logloss:0.40034
# [32]	validation_0-logloss:0.40201
# [33]	validation_0-logloss:0.40542
# [0]	validation_0-logloss:0.58893
# [1]	validation_0-logloss:0.52907
# [2]	validation_0-logloss:0.47973
# [3]	validation_0-logloss:0.44623
# [4]	validation_0-logloss:0.41987
# [5]	validation_0-logloss:0.40494
# [6]	validation_0-logloss:0.39634
# [7]	validation_0-logloss:0.38963
# [8]	validation_0-logloss:0.37646
# [9]	validation_0-logloss:0.37232
# [10]	validation_0-logloss:0.36795
# [11]	validation_0-logloss:0.36570
# [12]	validation_0-logloss:0.36478
# [13]	validation_0-logloss:0.36643
# [14]	validation_0-logloss:0.36466
# [15]	validation_0-logloss:0.36415
# [16]	validation_0-logloss:0.36790
# [17]	validation_0-logloss:0.37209
# [18]	validation_0-logloss:0.37176
# [19]	validation_0-logloss:0.37206
# [20]	validation_0-logloss:0.37328
# [21]	validation_0-logloss:0.37425
# [22]	validation_0-logloss:0.37470
# [23]	validation_0-logloss:0.37702
# [24]	validation_0-logloss:0.37715
# [25]	validation_0-logloss:0.37679
# [26]	validation_0-logloss:0.37987
# [27]	validation_0-logloss:0.38350
# [28]	validation_0-logloss:0.38630
# [29]	validation_0-logloss:0.38285
# [30]	validation_0-logloss:0.37964
# [31]	validation_0-logloss:0.38436
# [32]	validation_0-logloss:0.38872
# [33]	validation_0-logloss:0.38996
# [0]	validation_0-logloss:0.60209
# [1]	validation_0-logloss:0.54652
# [2]	validation_0-logloss:0.50296
# [3]	validation_0-logloss:0.47962
# [4]	validation_0-logloss:0.45896
# [5]	validation_0-logloss:0.44384
# [6]	validation_0-logloss:0.43184
# [7]	validation_0-logloss:0.42023
# [8]	validation_0-logloss:0.41515
# [9]	validation_0-logloss:0.41437
# [10]	validation_0-logloss:0.40838
# [11]	validation_0-logloss:0.41076
# [12]	validation_0-logloss:0.40712
# [13]	validation_0-logloss:0.40615
# [14]	validation_0-logloss:0.40769
# [15]	validation_0-logloss:0.40802
# [16]	validation_0-logloss:0.41252
# [17]	validation_0-logloss:0.41880
# [18]	validation_0-logloss:0.42056
# [19]	validation_0-logloss:0.42154
# [20]	validation_0-logloss:0.42383
# [21]	validation_0-logloss:0.42746
# [22]	validation_0-logloss:0.43129
# [23]	validation_0-logloss:0.43460
# [24]	validation_0-logloss:0.43772
# [25]	validation_0-logloss:0.44008
# [26]	validation_0-logloss:0.44159
# [27]	validation_0-logloss:0.44230
# [28]	validation_0-logloss:0.44966
# [29]	validation_0-logloss:0.45877
# [30]	validation_0-logloss:0.46074
# [31]	validation_0-logloss:0.45845
# [32]	validation_0-logloss:0.46000
# [33]	validation_0-logloss:0.46005
# [0]	validation_0-logloss:0.61810
# [1]	validation_0-logloss:0.56018
# [2]	validation_0-logloss:0.51648
# [3]	validation_0-logloss:0.48645
# [4]	validation_0-logloss:0.46276
# [5]	validation_0-logloss:0.44235
# [6]	validation_0-logloss:0.42526
# [7]	validation_0-logloss:0.42114
# [8]	validation_0-logloss:0.41157
# [9]	validation_0-logloss:0.40799
# [10]	validation_0-logloss:0.39979
# [11]	validation_0-logloss:0.39705
# [12]	validation_0-logloss:0.38890
# [13]	validation_0-logloss:0.39068
# [14]	validation_0-logloss:0.39030
# [15]	validation_0-logloss:0.38813
# [16]	validation_0-logloss:0.38843
# [17]	validation_0-logloss:0.39079
# [18]	validation_0-logloss:0.39273
# [19]	validation_0-logloss:0.39455
# [20]	validation_0-logloss:0.39327
# [21]	validation_0-logloss:0.39377
# [22]	validation_0-logloss:0.39358
# [23]	validation_0-logloss:0.39378
# [24]	validation_0-logloss:0.38815
# [25]	validation_0-logloss:0.38609
# [26]	validation_0-logloss:0.38482
# [27]	validation_0-logloss:0.38408
# [28]	validation_0-logloss:0.38406
# [29]	validation_0-logloss:0.38242
# [30]	validation_0-logloss:0.38453
# [31]	validation_0-logloss:0.38589
# [32]	validation_0-logloss:0.38756
# [33]	validation_0-logloss:0.38941
# [0]	validation_0-logloss:0.61300
# [1]	validation_0-logloss:0.56090
# [2]	validation_0-logloss:0.51665
# [3]	validation_0-logloss:0.48337
# [4]	validation_0-logloss:0.45717
# [5]	validation_0-logloss:0.43490
# [6]	validation_0-logloss:0.41805
# [7]	validation_0-logloss:0.40309
# [8]	validation_0-logloss:0.39312
# [9]	validation_0-logloss:0.38750
# [10]	validation_0-logloss:0.38251
# [11]	validation_0-logloss:0.37581
# [12]	validation_0-logloss:0.37189
# [13]	validation_0-logloss:0.36935
# [14]	validation_0-logloss:0.36634
# [15]	validation_0-logloss:0.36536
# [16]	validation_0-logloss:0.36992
# [17]	validation_0-logloss:0.36790
# [18]	validation_0-logloss:0.37064
# [19]	validation_0-logloss:0.37085
# [20]	validation_0-logloss:0.36854
# [21]	validation_0-logloss:0.36725
# [22]	validation_0-logloss:0.36804
# [23]	validation_0-logloss:0.36792
# [24]	validation_0-logloss:0.36828
# [25]	validation_0-logloss:0.37087
# [26]	validation_0-logloss:0.37120
# [27]	validation_0-logloss:0.37379
# [28]	validation_0-logloss:0.37458
# [29]	validation_0-logloss:0.37393
# [30]	validation_0-logloss:0.37486
# [31]	validation_0-logloss:0.37606
# [32]	validation_0-logloss:0.37812
# [33]	validation_0-logloss:0.37920
# [0]	validation_0-logloss:0.62268
# [1]	validation_0-logloss:0.56886
# [2]	validation_0-logloss:0.52897
# [3]	validation_0-logloss:0.50486
# [4]	validation_0-logloss:0.48034
# [5]	validation_0-logloss:0.46318
# [6]	validation_0-logloss:0.44849
# [7]	validation_0-logloss:0.43897
# [8]	validation_0-logloss:0.43083
# [9]	validation_0-logloss:0.42093
# [10]	validation_0-logloss:0.41244
# [11]	validation_0-logloss:0.41044
# [12]	validation_0-logloss:0.40833
# [13]	validation_0-logloss:0.40469
# [14]	validation_0-logloss:0.40247
# [15]	validation_0-logloss:0.40060
# [16]	validation_0-logloss:0.39694
# [17]	validation_0-logloss:0.39618
# [18]	validation_0-logloss:0.39577
# [19]	validation_0-logloss:0.40004
# [20]	validation_0-logloss:0.40152
# [21]	validation_0-logloss:0.40220
# [22]	validation_0-logloss:0.40531
# [23]	validation_0-logloss:0.40856
# [24]	validation_0-logloss:0.40901
# [25]	validation_0-logloss:0.41196
# [26]	validation_0-logloss:0.41775
# [27]	validation_0-logloss:0.42099
# [28]	validation_0-logloss:0.42258
# [29]	validation_0-logloss:0.42082
# [30]	validation_0-logloss:0.42171
# [31]	validation_0-logloss:0.42147
# [32]	validation_0-logloss:0.42396
# [33]	validation_0-logloss:0.42555
# [0]	validation_0-logloss:0.61549
# [1]	validation_0-logloss:0.55629
# [2]	validation_0-logloss:0.51207
# [3]	validation_0-logloss:0.48207
# [4]	validation_0-logloss:0.45992
# [5]	validation_0-logloss:0.43961
# [6]	validation_0-logloss:0.42282
# [7]	validation_0-logloss:0.41241
# [8]	validation_0-logloss:0.39748
# [9]	validation_0-logloss:0.39240
# [10]	validation_0-logloss:0.38341
# [11]	validation_0-logloss:0.37911
# [12]	validation_0-logloss:0.37834
# [13]	validation_0-logloss:0.37839
# [14]	validation_0-logloss:0.37950
# [15]	validation_0-logloss:0.38028
# [16]	validation_0-logloss:0.38075
# [17]	validation_0-logloss:0.38086
# [18]	validation_0-logloss:0.38267
# [19]	validation_0-logloss:0.38171
# [20]	validation_0-logloss:0.38217
# [21]	validation_0-logloss:0.38209
# [22]	validation_0-logloss:0.38215
# [23]	validation_0-logloss:0.38194
# [24]	validation_0-logloss:0.38305
# [25]	validation_0-logloss:0.38112
# [26]	validation_0-logloss:0.38443
# [27]	validation_0-logloss:0.38632
# [28]	validation_0-logloss:0.38615
# [29]	validation_0-logloss:0.38546
# [30]	validation_0-logloss:0.38872
# [31]	validation_0-logloss:0.38674
# [32]	validation_0-logloss:0.38692
# [33]	validation_0-logloss:0.38612
# [0]	validation_0-logloss:0.61017
# [1]	validation_0-logloss:0.55697
# [2]	validation_0-logloss:0.51211
# [3]	validation_0-logloss:0.47870
# [4]	validation_0-logloss:0.45266
# [5]	validation_0-logloss:0.43306
# [6]	validation_0-logloss:0.41453
# [7]	validation_0-logloss:0.40373
# [8]	validation_0-logloss:0.39498
# [9]	validation_0-logloss:0.38438
# [10]	validation_0-logloss:0.38339
# [11]	validation_0-logloss:0.38012
# [12]	validation_0-logloss:0.37528
# [13]	validation_0-logloss:0.37349
# [14]	validation_0-logloss:0.37200
# [15]	validation_0-logloss:0.36925
# [16]	validation_0-logloss:0.37181
# [17]	validation_0-logloss:0.37027
# [18]	validation_0-logloss:0.37065
# [19]	validation_0-logloss:0.37076
# [20]	validation_0-logloss:0.37304
# [21]	validation_0-logloss:0.37500
# [22]	validation_0-logloss:0.37291
# [23]	validation_0-logloss:0.37686
# [24]	validation_0-logloss:0.38209
# [25]	validation_0-logloss:0.38294
# [26]	validation_0-logloss:0.38413
# [27]	validation_0-logloss:0.38551
# [28]	validation_0-logloss:0.38686
# [29]	validation_0-logloss:0.39112
# [30]	validation_0-logloss:0.39017
# [31]	validation_0-logloss:0.39147
# [32]	validation_0-logloss:0.39625
# [33]	validation_0-logloss:0.39448
# [0]	validation_0-logloss:0.62023
# [1]	validation_0-logloss:0.56527
# [2]	validation_0-logloss:0.52493
# [3]	validation_0-logloss:0.50104
# [4]	validation_0-logloss:0.47668
# [5]	validation_0-logloss:0.45984
# [6]	validation_0-logloss:0.44553
# [7]	validation_0-logloss:0.43191
# [8]	validation_0-logloss:0.42388
# [9]	validation_0-logloss:0.41318
# [10]	validation_0-logloss:0.40528
# [11]	validation_0-logloss:0.40025
# [12]	validation_0-logloss:0.39271
# [13]	validation_0-logloss:0.38950
# [14]	validation_0-logloss:0.38855
# [15]	validation_0-logloss:0.39010
# [16]	validation_0-logloss:0.38730
# [17]	validation_0-logloss:0.39147
# [18]	validation_0-logloss:0.38875
# [19]	validation_0-logloss:0.39219
# [20]	validation_0-logloss:0.39695
# [21]	validation_0-logloss:0.39609
# [22]	validation_0-logloss:0.39778
# [23]	validation_0-logloss:0.39768
# [24]	validation_0-logloss:0.39782
# [25]	validation_0-logloss:0.39943
# [26]	validation_0-logloss:0.40237
# [27]	validation_0-logloss:0.40409
# [28]	validation_0-logloss:0.40624
# [29]	validation_0-logloss:0.40829
# [30]	validation_0-logloss:0.41133
# [31]	validation_0-logloss:0.41445
# [32]	validation_0-logloss:0.41471
# [33]	validation_0-logloss:0.41389
# [0]	validation_0-logloss:0.65407
# [1]	validation_0-logloss:0.61856
# [2]	validation_0-logloss:0.58826
# [3]	validation_0-logloss:0.56661
# [4]	validation_0-logloss:0.54385
# [5]	validation_0-logloss:0.52540
# [6]	validation_0-logloss:0.50713
# [7]	validation_0-logloss:0.49136
# [8]	validation_0-logloss:0.47874
# [9]	validation_0-logloss:0.46716
# [10]	validation_0-logloss:0.45800
# [11]	validation_0-logloss:0.45140
# [12]	validation_0-logloss:0.44388
# [13]	validation_0-logloss:0.43673
# [14]	validation_0-logloss:0.43134
# [15]	validation_0-logloss:0.42611
# [16]	validation_0-logloss:0.41890
# [17]	validation_0-logloss:0.41391
# [18]	validation_0-logloss:0.41021
# [19]	validation_0-logloss:0.40528
# [20]	validation_0-logloss:0.40264
# [21]	validation_0-logloss:0.40061
# [22]	validation_0-logloss:0.39625
# [23]	validation_0-logloss:0.39311
# [24]	validation_0-logloss:0.39049
# [25]	validation_0-logloss:0.38962
# [26]	validation_0-logloss:0.38918
# [27]	validation_0-logloss:0.38887
# [28]	validation_0-logloss:0.38664
# [29]	validation_0-logloss:0.38642
# [30]	validation_0-logloss:0.38641
# [31]	validation_0-logloss:0.38698
# [32]	validation_0-logloss:0.38778
# [33]	validation_0-logloss:0.38802
# [0]	validation_0-logloss:0.65172
# [1]	validation_0-logloss:0.61850
# [2]	validation_0-logloss:0.59050
# [3]	validation_0-logloss:0.56293
# [4]	validation_0-logloss:0.54066
# [5]	validation_0-logloss:0.51963
# [6]	validation_0-logloss:0.50030
# [7]	validation_0-logloss:0.48410
# [8]	validation_0-logloss:0.46919
# [9]	validation_0-logloss:0.45827
# [10]	validation_0-logloss:0.44662
# [11]	validation_0-logloss:0.43659
# [12]	validation_0-logloss:0.42713
# [13]	validation_0-logloss:0.41973
# [14]	validation_0-logloss:0.41324
# [15]	validation_0-logloss:0.40769
# [16]	validation_0-logloss:0.40347
# [17]	validation_0-logloss:0.39893
# [18]	validation_0-logloss:0.39597
# [19]	validation_0-logloss:0.39196
# [20]	validation_0-logloss:0.38902
# [21]	validation_0-logloss:0.38415
# [22]	validation_0-logloss:0.37914
# [23]	validation_0-logloss:0.37559
# [24]	validation_0-logloss:0.37244
# [25]	validation_0-logloss:0.36969
# [26]	validation_0-logloss:0.36769
# [27]	validation_0-logloss:0.36502
# [28]	validation_0-logloss:0.36227
# [29]	validation_0-logloss:0.35995
# [30]	validation_0-logloss:0.35878
# [31]	validation_0-logloss:0.35844
# [32]	validation_0-logloss:0.35814
# [33]	validation_0-logloss:0.35782
# [0]	validation_0-logloss:0.65640
# [1]	validation_0-logloss:0.62426
# [2]	validation_0-logloss:0.59734
# [3]	validation_0-logloss:0.57407
# [4]	validation_0-logloss:0.55368
# [5]	validation_0-logloss:0.53561
# [6]	validation_0-logloss:0.52066
# [7]	validation_0-logloss:0.50822
# [8]	validation_0-logloss:0.49519
# [9]	validation_0-logloss:0.48518
# [10]	validation_0-logloss:0.47550
# [11]	validation_0-logloss:0.46771
# [12]	validation_0-logloss:0.45871
# [13]	validation_0-logloss:0.45237
# [14]	validation_0-logloss:0.44620
# [15]	validation_0-logloss:0.43955
# [16]	validation_0-logloss:0.43363
# [17]	validation_0-logloss:0.42963
# [18]	validation_0-logloss:0.42537
# [19]	validation_0-logloss:0.42200
# [20]	validation_0-logloss:0.41953
# [21]	validation_0-logloss:0.41585
# [22]	validation_0-logloss:0.41391
# [23]	validation_0-logloss:0.41061
# [24]	validation_0-logloss:0.40913
# [25]	validation_0-logloss:0.40473
# [26]	validation_0-logloss:0.40336
# [27]	validation_0-logloss:0.40320
# [28]	validation_0-logloss:0.40213
# [29]	validation_0-logloss:0.40004
# [30]	validation_0-logloss:0.39923
# [31]	validation_0-logloss:0.39943
# [32]	validation_0-logloss:0.39923
# [33]	validation_0-logloss:0.39862
# [0]	validation_0-logloss:0.60223
# [1]	validation_0-logloss:0.53706
# [2]	validation_0-logloss:0.49723
# [3]	validation_0-logloss:0.46677
# [4]	validation_0-logloss:0.44398
# [5]	validation_0-logloss:0.42934
# [6]	validation_0-logloss:0.41860
# [7]	validation_0-logloss:0.40729
# [8]	validation_0-logloss:0.39989
# [9]	validation_0-logloss:0.39200
# [10]	validation_0-logloss:0.38879
# [11]	validation_0-logloss:0.38742
# [12]	validation_0-logloss:0.38846
# [13]	validation_0-logloss:0.39050
# [14]	validation_0-logloss:0.38917
# [15]	validation_0-logloss:0.38957
# [16]	validation_0-logloss:0.39459
# [17]	validation_0-logloss:0.39788
# [18]	validation_0-logloss:0.40060
# [19]	validation_0-logloss:0.40517
# [20]	validation_0-logloss:0.40738
# [21]	validation_0-logloss:0.40876
# [22]	validation_0-logloss:0.41385
# [23]	validation_0-logloss:0.41236
# [24]	validation_0-logloss:0.40952
# [25]	validation_0-logloss:0.41204
# [26]	validation_0-logloss:0.40977
# [27]	validation_0-logloss:0.41107
# [28]	validation_0-logloss:0.41446
# [29]	validation_0-logloss:0.41354
# [30]	validation_0-logloss:0.41311
# [31]	validation_0-logloss:0.41817
# [32]	validation_0-logloss:0.41901
# [33]	validation_0-logloss:0.41915
# [0]	validation_0-logloss:0.59569
# [1]	validation_0-logloss:0.53765
# [2]	validation_0-logloss:0.48908
# [3]	validation_0-logloss:0.45545
# [4]	validation_0-logloss:0.43057
# [5]	validation_0-logloss:0.41406
# [6]	validation_0-logloss:0.39713
# [7]	validation_0-logloss:0.39108
# [8]	validation_0-logloss:0.38513
# [9]	validation_0-logloss:0.37368
# [10]	validation_0-logloss:0.36858
# [11]	validation_0-logloss:0.36697
# [12]	validation_0-logloss:0.36753
# [13]	validation_0-logloss:0.36938
# [14]	validation_0-logloss:0.36590
# [15]	validation_0-logloss:0.37007
# [16]	validation_0-logloss:0.37175
# [17]	validation_0-logloss:0.37151
# [18]	validation_0-logloss:0.36806
# [19]	validation_0-logloss:0.36607
# [20]	validation_0-logloss:0.36794
# [21]	validation_0-logloss:0.36892
# [22]	validation_0-logloss:0.37050
# [23]	validation_0-logloss:0.37261
# [24]	validation_0-logloss:0.37374
# [25]	validation_0-logloss:0.37177
# [26]	validation_0-logloss:0.37104
# [27]	validation_0-logloss:0.37385
# [28]	validation_0-logloss:0.37690
# [29]	validation_0-logloss:0.37675
# [30]	validation_0-logloss:0.38100
# [31]	validation_0-logloss:0.38322
# [32]	validation_0-logloss:0.38404
# [33]	validation_0-logloss:0.38404
# [0]	validation_0-logloss:0.60783
# [1]	validation_0-logloss:0.54810
# [2]	validation_0-logloss:0.50505
# [3]	validation_0-logloss:0.47817
# [4]	validation_0-logloss:0.45875
# [5]	validation_0-logloss:0.43078
# [6]	validation_0-logloss:0.41933
# [7]	validation_0-logloss:0.40674
# [8]	validation_0-logloss:0.39769
# [9]	validation_0-logloss:0.39679
# [10]	validation_0-logloss:0.39453
# [11]	validation_0-logloss:0.39383
# [12]	validation_0-logloss:0.39332
# [13]	validation_0-logloss:0.38882
# [14]	validation_0-logloss:0.38805
# [15]	validation_0-logloss:0.39109
# [16]	validation_0-logloss:0.39178
# [17]	validation_0-logloss:0.39274
# [18]	validation_0-logloss:0.38950
# [19]	validation_0-logloss:0.39002
# [20]	validation_0-logloss:0.39509
# [21]	validation_0-logloss:0.39751
# [22]	validation_0-logloss:0.39943
# [23]	validation_0-logloss:0.39849
# [24]	validation_0-logloss:0.40141
# [25]	validation_0-logloss:0.40712
# [26]	validation_0-logloss:0.41165
# [27]	validation_0-logloss:0.41460
# [28]	validation_0-logloss:0.41242
# [29]	validation_0-logloss:0.41065
# [30]	validation_0-logloss:0.41143
# [31]	validation_0-logloss:0.41124
# [32]	validation_0-logloss:0.40892
# [33]	validation_0-logloss:0.40873
# [0]	validation_0-logloss:0.63412
# [1]	validation_0-logloss:0.58486
# [2]	validation_0-logloss:0.54561
# [3]	validation_0-logloss:0.51426
# [4]	validation_0-logloss:0.49029
# [5]	validation_0-logloss:0.47030
# [6]	validation_0-logloss:0.45308
# [7]	validation_0-logloss:0.44571
# [8]	validation_0-logloss:0.43241
# [9]	validation_0-logloss:0.42238
# [10]	validation_0-logloss:0.41205
# [11]	validation_0-logloss:0.40490
# [12]	validation_0-logloss:0.39926
# [13]	validation_0-logloss:0.39501
# [14]	validation_0-logloss:0.38833
# [15]	validation_0-logloss:0.38616
# [16]	validation_0-logloss:0.38266
# [17]	validation_0-logloss:0.38090
# [18]	validation_0-logloss:0.37886
# [19]	validation_0-logloss:0.37944
# [20]	validation_0-logloss:0.37889
# [21]	validation_0-logloss:0.37713
# [22]	validation_0-logloss:0.37934
# [23]	validation_0-logloss:0.38017
# [24]	validation_0-logloss:0.37916
# [25]	validation_0-logloss:0.38059
# [26]	validation_0-logloss:0.38128
# [27]	validation_0-logloss:0.38336
# [28]	validation_0-logloss:0.38415
# [29]	validation_0-logloss:0.38469
# [30]	validation_0-logloss:0.38583
# [31]	validation_0-logloss:0.38742
# [32]	validation_0-logloss:0.38630
# [33]	validation_0-logloss:0.38671
# [0]	validation_0-logloss:0.63033
# [1]	validation_0-logloss:0.58463
# [2]	validation_0-logloss:0.55104
# [3]	validation_0-logloss:0.51821
# [4]	validation_0-logloss:0.49309
# [5]	validation_0-logloss:0.47096
# [6]	validation_0-logloss:0.45373
# [7]	validation_0-logloss:0.43704
# [8]	validation_0-logloss:0.42317
# [9]	validation_0-logloss:0.41389
# [10]	validation_0-logloss:0.40270
# [11]	validation_0-logloss:0.39646
# [12]	validation_0-logloss:0.39173
# [13]	validation_0-logloss:0.38479
# [14]	validation_0-logloss:0.38123
# [15]	validation_0-logloss:0.37726
# [16]	validation_0-logloss:0.37360
# [17]	validation_0-logloss:0.36863
# [18]	validation_0-logloss:0.36735
# [19]	validation_0-logloss:0.36471
# [20]	validation_0-logloss:0.36330
# [21]	validation_0-logloss:0.36243
# [22]	validation_0-logloss:0.36135
# [23]	validation_0-logloss:0.36186
# [24]	validation_0-logloss:0.36184
# [25]	validation_0-logloss:0.36535
# [26]	validation_0-logloss:0.36399
# [27]	validation_0-logloss:0.36564
# [28]	validation_0-logloss:0.36859
# [29]	validation_0-logloss:0.36922
# [30]	validation_0-logloss:0.36745
# [31]	validation_0-logloss:0.36608
# [32]	validation_0-logloss:0.36612
# [33]	validation_0-logloss:0.36531
# [0]	validation_0-logloss:0.63769
# [1]	validation_0-logloss:0.59347
# [2]	validation_0-logloss:0.55913
# [3]	validation_0-logloss:0.53143
# [4]	validation_0-logloss:0.50946
# [5]	validation_0-logloss:0.48878
# [6]	validation_0-logloss:0.47073
# [7]	validation_0-logloss:0.45651
# [8]	validation_0-logloss:0.44759
# [9]	validation_0-logloss:0.43919
# [10]	validation_0-logloss:0.43014
# [11]	validation_0-logloss:0.42301
# [12]	validation_0-logloss:0.41955
# [13]	validation_0-logloss:0.41400
# [14]	validation_0-logloss:0.41065
# [15]	validation_0-logloss:0.40561
# [16]	validation_0-logloss:0.40312
# [17]	validation_0-logloss:0.40061
# [18]	validation_0-logloss:0.40089
# [19]	validation_0-logloss:0.40025
# [20]	validation_0-logloss:0.40185
# [21]	validation_0-logloss:0.40021
# [22]	validation_0-logloss:0.40004
# [23]	validation_0-logloss:0.39937
# [24]	validation_0-logloss:0.39984
# [25]	validation_0-logloss:0.40084
# [26]	validation_0-logloss:0.40047
# [27]	validation_0-logloss:0.40422
# [28]	validation_0-logloss:0.40500
# [29]	validation_0-logloss:0.40576
# [30]	validation_0-logloss:0.40883
# [31]	validation_0-logloss:0.41089
# [32]	validation_0-logloss:0.41111
# [33]	validation_0-logloss:0.41341
# [0]	validation_0-logloss:0.62128
# [1]	validation_0-logloss:0.56492
# [2]	validation_0-logloss:0.52194
# [3]	validation_0-logloss:0.49065
# [4]	validation_0-logloss:0.46723
# [5]	validation_0-logloss:0.44848
# [6]	validation_0-logloss:0.42989
# [7]	validation_0-logloss:0.41910
# [8]	validation_0-logloss:0.40720
# [9]	validation_0-logloss:0.40099
# [10]	validation_0-logloss:0.38857
# [11]	validation_0-logloss:0.38113
# [12]	validation_0-logloss:0.37893
# [13]	validation_0-logloss:0.37828
# [14]	validation_0-logloss:0.37757
# [15]	validation_0-logloss:0.37784
# [16]	validation_0-logloss:0.38084
# [17]	validation_0-logloss:0.38241
# [18]	validation_0-logloss:0.38306
# [19]	validation_0-logloss:0.38297
# [20]	validation_0-logloss:0.38366
# [21]	validation_0-logloss:0.38178
# [22]	validation_0-logloss:0.38355
# [23]	validation_0-logloss:0.38488
# [24]	validation_0-logloss:0.38558
# [25]	validation_0-logloss:0.38433
# [26]	validation_0-logloss:0.38602
# [27]	validation_0-logloss:0.38782
# [28]	validation_0-logloss:0.38742
# [29]	validation_0-logloss:0.38902
# [30]	validation_0-logloss:0.39069
# [31]	validation_0-logloss:0.39286
# [32]	validation_0-logloss:0.39155
# [33]	validation_0-logloss:0.39090
# [0]	validation_0-logloss:0.61645
# [1]	validation_0-logloss:0.56575
# [2]	validation_0-logloss:0.51982
# [3]	validation_0-logloss:0.48452
# [4]	validation_0-logloss:0.45672
# [5]	validation_0-logloss:0.43885
# [6]	validation_0-logloss:0.42127
# [7]	validation_0-logloss:0.40596
# [8]	validation_0-logloss:0.39637
# [9]	validation_0-logloss:0.38985
# [10]	validation_0-logloss:0.38402
# [11]	validation_0-logloss:0.37952
# [12]	validation_0-logloss:0.37165
# [13]	validation_0-logloss:0.36882
# [14]	validation_0-logloss:0.36449
# [15]	validation_0-logloss:0.36128
# [16]	validation_0-logloss:0.35950
# [17]	validation_0-logloss:0.35754
# [18]	validation_0-logloss:0.35370
# [19]	validation_0-logloss:0.35500
# [20]	validation_0-logloss:0.35779
# [21]	validation_0-logloss:0.35971
# [22]	validation_0-logloss:0.36051
# [23]	validation_0-logloss:0.36149
# [24]	validation_0-logloss:0.36414
# [25]	validation_0-logloss:0.36641
# [26]	validation_0-logloss:0.36484
# [27]	validation_0-logloss:0.36681
# [28]	validation_0-logloss:0.36732
# [29]	validation_0-logloss:0.36925
# [30]	validation_0-logloss:0.37312
# [31]	validation_0-logloss:0.37383
# [32]	validation_0-logloss:0.37509
# [33]	validation_0-logloss:0.37638
# [0]	validation_0-logloss:0.62565
# [1]	validation_0-logloss:0.57328
# [2]	validation_0-logloss:0.53401
# [3]	validation_0-logloss:0.50970
# [4]	validation_0-logloss:0.48463
# [5]	validation_0-logloss:0.46707
# [6]	validation_0-logloss:0.45462
# [7]	validation_0-logloss:0.44029
# [8]	validation_0-logloss:0.42890
# [9]	validation_0-logloss:0.41942
# [10]	validation_0-logloss:0.41165
# [11]	validation_0-logloss:0.40706
# [12]	validation_0-logloss:0.40115
# [13]	validation_0-logloss:0.39865
# [14]	validation_0-logloss:0.39606
# [15]	validation_0-logloss:0.39372
# [16]	validation_0-logloss:0.39499
# [17]	validation_0-logloss:0.39686
# [18]	validation_0-logloss:0.39613
# [19]	validation_0-logloss:0.39666
# [20]	validation_0-logloss:0.39751
# [21]	validation_0-logloss:0.39787
# [22]	validation_0-logloss:0.39850
# [23]	validation_0-logloss:0.40318
# [24]	validation_0-logloss:0.40701
# [25]	validation_0-logloss:0.40541
# [26]	validation_0-logloss:0.40680
# [27]	validation_0-logloss:0.41127
# [28]	validation_0-logloss:0.41198
# [29]	validation_0-logloss:0.41339
# [30]	validation_0-logloss:0.41484
# [31]	validation_0-logloss:0.41661
# [32]	validation_0-logloss:0.41871
# [33]	validation_0-logloss:0.42245
# [0]	validation_0-logloss:0.59182
# [1]	validation_0-logloss:0.52341
# [2]	validation_0-logloss:0.48296
# [3]	validation_0-logloss:0.45642
# [4]	validation_0-logloss:0.43190
# [5]	validation_0-logloss:0.41255
# [6]	validation_0-logloss:0.39725
# [7]	validation_0-logloss:0.39113
# [8]	validation_0-logloss:0.38383
# [9]	validation_0-logloss:0.38349
# [10]	validation_0-logloss:0.38552
# [11]	validation_0-logloss:0.38367
# [12]	validation_0-logloss:0.38294
# [13]	validation_0-logloss:0.38229
# [14]	validation_0-logloss:0.38433
# [15]	validation_0-logloss:0.38305
# [16]	validation_0-logloss:0.38721
# [17]	validation_0-logloss:0.38843
# [18]	validation_0-logloss:0.38627
# [19]	validation_0-logloss:0.38904
# [20]	validation_0-logloss:0.38906
# [21]	validation_0-logloss:0.39006
# [22]	validation_0-logloss:0.39505
# [23]	validation_0-logloss:0.39461
# [24]	validation_0-logloss:0.39369
# [25]	validation_0-logloss:0.39315
# [26]	validation_0-logloss:0.39491
# [27]	validation_0-logloss:0.39674
# [28]	validation_0-logloss:0.40272
# [29]	validation_0-logloss:0.40650
# [30]	validation_0-logloss:0.40943
# [31]	validation_0-logloss:0.41112
# [32]	validation_0-logloss:0.41040
# [33]	validation_0-logloss:0.41048
# [0]	validation_0-logloss:0.58423
# [1]	validation_0-logloss:0.52326
# [2]	validation_0-logloss:0.47248
# [3]	validation_0-logloss:0.44154
# [4]	validation_0-logloss:0.42153
# [5]	validation_0-logloss:0.40814
# [6]	validation_0-logloss:0.39638
# [7]	validation_0-logloss:0.39566
# [8]	validation_0-logloss:0.39249
# [9]	validation_0-logloss:0.38450
# [10]	validation_0-logloss:0.37753
# [11]	validation_0-logloss:0.37776
# [12]	validation_0-logloss:0.38213
# [13]	validation_0-logloss:0.38661
# [14]	validation_0-logloss:0.38499
# [15]	validation_0-logloss:0.38759
# [16]	validation_0-logloss:0.38932
# [17]	validation_0-logloss:0.39072
# [18]	validation_0-logloss:0.39387
# [19]	validation_0-logloss:0.39355
# [20]	validation_0-logloss:0.39688
# [21]	validation_0-logloss:0.39378
# [22]	validation_0-logloss:0.39711
# [23]	validation_0-logloss:0.40232
# [24]	validation_0-logloss:0.40336
# [25]	validation_0-logloss:0.40679
# [26]	validation_0-logloss:0.41051
# [27]	validation_0-logloss:0.41403
# [28]	validation_0-logloss:0.41394
# [29]	validation_0-logloss:0.41682
# [30]	validation_0-logloss:0.41725
# [31]	validation_0-logloss:0.42027
# [32]	validation_0-logloss:0.41699
# [33]	validation_0-logloss:0.41948
# [0]	validation_0-logloss:0.59810
# [1]	validation_0-logloss:0.53876
# [2]	validation_0-logloss:0.49670
# [3]	validation_0-logloss:0.46834
# [4]	validation_0-logloss:0.45272
# [5]	validation_0-logloss:0.43938
# [6]	validation_0-logloss:0.42596
# [7]	validation_0-logloss:0.41797
# [8]	validation_0-logloss:0.40826
# [9]	validation_0-logloss:0.40850
# [10]	validation_0-logloss:0.40766
# [11]	validation_0-logloss:0.40522
# [12]	validation_0-logloss:0.40470
# [13]	validation_0-logloss:0.40549
# [14]	validation_0-logloss:0.40489
# [15]	validation_0-logloss:0.40857
# [16]	validation_0-logloss:0.41104
# [17]	validation_0-logloss:0.41201
# [18]	validation_0-logloss:0.41853
# [19]	validation_0-logloss:0.41811
# [20]	validation_0-logloss:0.41677
# [21]	validation_0-logloss:0.41993
# [22]	validation_0-logloss:0.42866
# [23]	validation_0-logloss:0.43702
# [24]	validation_0-logloss:0.43795
# [25]	validation_0-logloss:0.44480
# [26]	validation_0-logloss:0.44889
# [27]	validation_0-logloss:0.44955
# [28]	validation_0-logloss:0.45171
# [29]	validation_0-logloss:0.44926
# [30]	validation_0-logloss:0.45626
# [31]	validation_0-logloss:0.45367
# [32]	validation_0-logloss:0.45752
# [33]	validation_0-logloss:0.45872
# [0]	validation_0-logloss:0.64565
# [1]	validation_0-logloss:0.60399
# [2]	validation_0-logloss:0.56955
# [3]	validation_0-logloss:0.54619
# [4]	validation_0-logloss:0.52189
# [5]	validation_0-logloss:0.50131
# [6]	validation_0-logloss:0.48582
# [7]	validation_0-logloss:0.47453
# [8]	validation_0-logloss:0.46300
# [9]	validation_0-logloss:0.45271
# [10]	validation_0-logloss:0.44197
# [11]	validation_0-logloss:0.43313
# [12]	validation_0-logloss:0.42753
# [13]	validation_0-logloss:0.42137
# [14]	validation_0-logloss:0.41315
# [15]	validation_0-logloss:0.40911
# [16]	validation_0-logloss:0.40560
# [17]	validation_0-logloss:0.40175
# [18]	validation_0-logloss:0.39966
# [19]	validation_0-logloss:0.39780
# [20]	validation_0-logloss:0.39678
# [21]	validation_0-logloss:0.39089
# [22]	validation_0-logloss:0.39203
# [23]	validation_0-logloss:0.39153
# [24]	validation_0-logloss:0.38987
# [25]	validation_0-logloss:0.38943
# [26]	validation_0-logloss:0.39013
# [27]	validation_0-logloss:0.38990
# [28]	validation_0-logloss:0.39200
# [29]	validation_0-logloss:0.39158
# [30]	validation_0-logloss:0.39089
# [31]	validation_0-logloss:0.39107
# [32]	validation_0-logloss:0.39300
# [33]	validation_0-logloss:0.39305
# [0]	validation_0-logloss:0.64271
# [1]	validation_0-logloss:0.60387
# [2]	validation_0-logloss:0.57201
# [3]	validation_0-logloss:0.54669
# [4]	validation_0-logloss:0.52079
# [5]	validation_0-logloss:0.49987
# [6]	validation_0-logloss:0.48001
# [7]	validation_0-logloss:0.46393
# [8]	validation_0-logloss:0.44915
# [9]	validation_0-logloss:0.43797
# [10]	validation_0-logloss:0.42925
# [11]	validation_0-logloss:0.41906
# [12]	validation_0-logloss:0.41176
# [13]	validation_0-logloss:0.40591
# [14]	validation_0-logloss:0.40038
# [15]	validation_0-logloss:0.39646
# [16]	validation_0-logloss:0.39223
# [17]	validation_0-logloss:0.38802
# [18]	validation_0-logloss:0.38458
# [19]	validation_0-logloss:0.38369
# [20]	validation_0-logloss:0.37984
# [21]	validation_0-logloss:0.37546
# [22]	validation_0-logloss:0.37250
# [23]	validation_0-logloss:0.37157
# [24]	validation_0-logloss:0.37059
# [25]	validation_0-logloss:0.37045
# [26]	validation_0-logloss:0.36889
# [27]	validation_0-logloss:0.36848
# [28]	validation_0-logloss:0.36818
# [29]	validation_0-logloss:0.36602
# [30]	validation_0-logloss:0.36936
# [31]	validation_0-logloss:0.37135
# [32]	validation_0-logloss:0.37039
# [33]	validation_0-logloss:0.37287
# [0]	validation_0-logloss:0.64850
# [1]	validation_0-logloss:0.61091
# [2]	validation_0-logloss:0.58221
# [3]	validation_0-logloss:0.55670
# [4]	validation_0-logloss:0.53379
# [5]	validation_0-logloss:0.51550
# [6]	validation_0-logloss:0.49773
# [7]	validation_0-logloss:0.48167
# [8]	validation_0-logloss:0.47107
# [9]	validation_0-logloss:0.46171
# [10]	validation_0-logloss:0.45216
# [11]	validation_0-logloss:0.44530
# [12]	validation_0-logloss:0.43895
# [13]	validation_0-logloss:0.43178
# [14]	validation_0-logloss:0.42725
# [15]	validation_0-logloss:0.42346
# [16]	validation_0-logloss:0.41841
# [17]	validation_0-logloss:0.41468
# [18]	validation_0-logloss:0.41149
# [19]	validation_0-logloss:0.40734
# [20]	validation_0-logloss:0.40417
# [21]	validation_0-logloss:0.40028
# [22]	validation_0-logloss:0.39659
# [23]	validation_0-logloss:0.39476
# [24]	validation_0-logloss:0.39479
# [25]	validation_0-logloss:0.39591
# [26]	validation_0-logloss:0.39363
# [27]	validation_0-logloss:0.39463
# [28]	validation_0-logloss:0.39487
# [29]	validation_0-logloss:0.39478
# [30]	validation_0-logloss:0.39564
# [31]	validation_0-logloss:0.39541
# [32]	validation_0-logloss:0.39406
# [33]	validation_0-logloss:0.39418
# [0]	validation_0-logloss:0.67514
# [1]	validation_0-logloss:0.65895
# [2]	validation_0-logloss:0.64227
# [3]	validation_0-logloss:0.62725
# [4]	validation_0-logloss:0.61528
# [5]	validation_0-logloss:0.60195
# [6]	validation_0-logloss:0.58913
# [7]	validation_0-logloss:0.57655
# [8]	validation_0-logloss:0.56620
# [9]	validation_0-logloss:0.55760
# [10]	validation_0-logloss:0.54770
# [11]	validation_0-logloss:0.53918
# [12]	validation_0-logloss:0.53019
# [13]	validation_0-logloss:0.52190
# [14]	validation_0-logloss:0.51376
# [15]	validation_0-logloss:0.50676
# [16]	validation_0-logloss:0.49925
# [17]	validation_0-logloss:0.49277
# [18]	validation_0-logloss:0.48667
# [19]	validation_0-logloss:0.48113
# [20]	validation_0-logloss:0.47574
# [21]	validation_0-logloss:0.47061
# [22]	validation_0-logloss:0.46617
# [23]	validation_0-logloss:0.46254
# [24]	validation_0-logloss:0.45831
# [25]	validation_0-logloss:0.45356
# [26]	validation_0-logloss:0.44986
# [27]	validation_0-logloss:0.44564
# [28]	validation_0-logloss:0.44148
# [29]	validation_0-logloss:0.43834
# [30]	validation_0-logloss:0.43687
# [31]	validation_0-logloss:0.43372
# [32]	validation_0-logloss:0.43056
# [33]	validation_0-logloss:0.42780
# [0]	validation_0-logloss:0.67412
# [1]	validation_0-logloss:0.65736
# [2]	validation_0-logloss:0.64214
# [3]	validation_0-logloss:0.62690
# [4]	validation_0-logloss:0.61372
# [5]	validation_0-logloss:0.60084
# [6]	validation_0-logloss:0.58756
# [7]	validation_0-logloss:0.57530
# [8]	validation_0-logloss:0.56357
# [9]	validation_0-logloss:0.55262
# [10]	validation_0-logloss:0.54247
# [11]	validation_0-logloss:0.53324
# [12]	validation_0-logloss:0.52443
# [13]	validation_0-logloss:0.51547
# [14]	validation_0-logloss:0.50683
# [15]	validation_0-logloss:0.49901
# [16]	validation_0-logloss:0.49188
# [17]	validation_0-logloss:0.48485
# [18]	validation_0-logloss:0.47813
# [19]	validation_0-logloss:0.47204
# [20]	validation_0-logloss:0.46618
# [21]	validation_0-logloss:0.46026
# [22]	validation_0-logloss:0.45489
# [23]	validation_0-logloss:0.45037
# [24]	validation_0-logloss:0.44538
# [25]	validation_0-logloss:0.44068
# [26]	validation_0-logloss:0.43619
# [27]	validation_0-logloss:0.43206
# [28]	validation_0-logloss:0.42791
# [29]	validation_0-logloss:0.42508
# ...
# [17]	validation_0-logloss:0.39006
# [18]	validation_0-logloss:0.39240
# [19]	validation_0-logloss:0.39058
# [20]	validation_0-logloss:0.38912
# [21]	validation_0-logloss:0.39129
# [22]	validation_0-logloss:0.39310
# [23]	validation_0-logloss:0.39384
# [24]	validation_0-logloss:0.39105
# [25]	validation_0-logloss:0.39191
# [26]	validation_0-logloss:0.39001
# [27]	validation_0-logloss:0.39049
# [28]	validation_0-logloss:0.39496
# [29]	validation_0-logloss:0.39548
# [30]	validation_0-logloss:0.39528
# [31]	validation_0-logloss:0.39974
# [32]	validation_0-logloss:0.39949
# [33]	validation_0-logloss:0.39717
# [0]	validation_0-logloss:0.59892
# [1]	validation_0-logloss:0.54185
# [2]	validation_0-logloss:0.49373
# [3]	validation_0-logloss:0.46006
# [4]	validation_0-logloss:0.43597
# [5]	validation_0-logloss:0.41928
# [6]	validation_0-logloss:0.40652
# [7]	validation_0-logloss:0.39829
# [8]	validation_0-logloss:0.39219
# [9]	validation_0-logloss:0.38043
# [10]	validation_0-logloss:0.37403
# [11]	validation_0-logloss:0.36878
# [12]	validation_0-logloss:0.36556
# [13]	validation_0-logloss:0.36333
# [14]	validation_0-logloss:0.36591
# [15]	validation_0-logloss:0.36662
# [16]	validation_0-logloss:0.36303
# [17]	validation_0-logloss:0.36753
# [18]	validation_0-logloss:0.36549
# [19]	validation_0-logloss:0.36275
# [20]	validation_0-logloss:0.36440
# [21]	validation_0-logloss:0.36859
# [22]	validation_0-logloss:0.36828
# [23]	validation_0-logloss:0.36914
# [24]	validation_0-logloss:0.37038
# [25]	validation_0-logloss:0.37198
# [26]	validation_0-logloss:0.37317
# [27]	validation_0-logloss:0.37481
# [28]	validation_0-logloss:0.37635
# [29]	validation_0-logloss:0.37952
# [30]	validation_0-logloss:0.37993
# [31]	validation_0-logloss:0.38248
# [32]	validation_0-logloss:0.38677
# [33]	validation_0-logloss:0.38994
# [0]	validation_0-logloss:0.61059
# [1]	validation_0-logloss:0.55162
# [2]	validation_0-logloss:0.50909
# [3]	validation_0-logloss:0.48191
# [4]	validation_0-logloss:0.46199
# [5]	validation_0-logloss:0.44586
# [6]	validation_0-logloss:0.43520
# [7]	validation_0-logloss:0.42530
# [8]	validation_0-logloss:0.41552
# [9]	validation_0-logloss:0.41074
# [10]	validation_0-logloss:0.40963
# [11]	validation_0-logloss:0.40870
# [12]	validation_0-logloss:0.40481
# [13]	validation_0-logloss:0.40820
# [14]	validation_0-logloss:0.40724
# [15]	validation_0-logloss:0.41028
# [16]	validation_0-logloss:0.41130
# [17]	validation_0-logloss:0.41024
# [18]	validation_0-logloss:0.41144
# [19]	validation_0-logloss:0.41388
# [20]	validation_0-logloss:0.41409
# [21]	validation_0-logloss:0.41962
# [22]	validation_0-logloss:0.41702
# [23]	validation_0-logloss:0.41881
# [24]	validation_0-logloss:0.41889
# [25]	validation_0-logloss:0.42373
# [26]	validation_0-logloss:0.42243
# [27]	validation_0-logloss:0.42695
# [28]	validation_0-logloss:0.42585
# [29]	validation_0-logloss:0.42440
# [30]	validation_0-logloss:0.42578
# [31]	validation_0-logloss:0.42809
# [32]	validation_0-logloss:0.43374
# [33]	validation_0-logloss:0.43509
# [0]	validation_0-logloss:0.66873
# [1]	validation_0-logloss:0.64744
# [2]	validation_0-logloss:0.62588
# [3]	validation_0-logloss:0.60699
# [4]	validation_0-logloss:0.59026
# [5]	validation_0-logloss:0.57413
# [6]	validation_0-logloss:0.55867
# [7]	validation_0-logloss:0.54558
# [8]	validation_0-logloss:0.53402
# [9]	validation_0-logloss:0.52381
# [10]	validation_0-logloss:0.51269
# [11]	validation_0-logloss:0.50262
# [12]	validation_0-logloss:0.49389
# [13]	validation_0-logloss:0.48488
# [14]	validation_0-logloss:0.47741
# [15]	validation_0-logloss:0.47040
# [16]	validation_0-logloss:0.46475
# [17]	validation_0-logloss:0.45992
# [18]	validation_0-logloss:0.45385
# [19]	validation_0-logloss:0.44847
# [20]	validation_0-logloss:0.44397
# [21]	validation_0-logloss:0.43929
# [22]	validation_0-logloss:0.43476
# [23]	validation_0-logloss:0.42976
# [24]	validation_0-logloss:0.42600
# [25]	validation_0-logloss:0.42138
# [26]	validation_0-logloss:0.41798
# [27]	validation_0-logloss:0.41512
# [28]	validation_0-logloss:0.41201
# [29]	validation_0-logloss:0.40896
# [30]	validation_0-logloss:0.40702
# [31]	validation_0-logloss:0.40455
# [32]	validation_0-logloss:0.40247
# [33]	validation_0-logloss:0.40037
# [0]	validation_0-logloss:0.66733
# [1]	validation_0-logloss:0.64521
# [2]	validation_0-logloss:0.62567
# [3]	validation_0-logloss:0.60648
# [4]	validation_0-logloss:0.59005
# [5]	validation_0-logloss:0.57281
# [6]	validation_0-logloss:0.55959
# [7]	validation_0-logloss:0.54452
# [8]	validation_0-logloss:0.53184
# [9]	validation_0-logloss:0.51930
# [10]	validation_0-logloss:0.50709
# [11]	validation_0-logloss:0.49643
# [12]	validation_0-logloss:0.48664
# [13]	validation_0-logloss:0.47731
# [14]	validation_0-logloss:0.46940
# [15]	validation_0-logloss:0.46113
# [16]	validation_0-logloss:0.45392
# [17]	validation_0-logloss:0.44722
# [18]	validation_0-logloss:0.44040
# [19]	validation_0-logloss:0.43533
# [20]	validation_0-logloss:0.42968
# [21]	validation_0-logloss:0.42442
# [22]	validation_0-logloss:0.42034
# [23]	validation_0-logloss:0.41695
# [24]	validation_0-logloss:0.41327
# [25]	validation_0-logloss:0.40993
# [26]	validation_0-logloss:0.40702
# [27]	validation_0-logloss:0.40364
# [28]	validation_0-logloss:0.40179
# [29]	validation_0-logloss:0.39899
# [30]	validation_0-logloss:0.39666
# [31]	validation_0-logloss:0.39461
# [32]	validation_0-logloss:0.39268
# [33]	validation_0-logloss:0.39127
# [0]	validation_0-logloss:0.67018
# [1]	validation_0-logloss:0.64876
# [2]	validation_0-logloss:0.62958
# [3]	validation_0-logloss:0.61416
# [4]	validation_0-logloss:0.59840
# [5]	validation_0-logloss:0.58546
# [6]	validation_0-logloss:0.57131
# [7]	validation_0-logloss:0.55879
# [8]	validation_0-logloss:0.54694
# [9]	validation_0-logloss:0.53590
# [10]	validation_0-logloss:0.52453
# [11]	validation_0-logloss:0.51578
# [12]	validation_0-logloss:0.50673
# [13]	validation_0-logloss:0.49966
# [14]	validation_0-logloss:0.49225
# [15]	validation_0-logloss:0.48481
# [16]	validation_0-logloss:0.47850
# [17]	validation_0-logloss:0.47236
# [18]	validation_0-logloss:0.46698
# [19]	validation_0-logloss:0.46110
# [20]	validation_0-logloss:0.45668
# [21]	validation_0-logloss:0.45202
# [22]	validation_0-logloss:0.44867
# [23]	validation_0-logloss:0.44411
# [24]	validation_0-logloss:0.44007
# [25]	validation_0-logloss:0.43636
# [26]	validation_0-logloss:0.43230
# [27]	validation_0-logloss:0.42976
# [28]	validation_0-logloss:0.42610
# [29]	validation_0-logloss:0.42309
# [30]	validation_0-logloss:0.42032
# [31]	validation_0-logloss:0.41881
# [32]	validation_0-logloss:0.41722
# [33]	validation_0-logloss:0.41544
# [0]	validation_0-logloss:0.57804
# [1]	validation_0-logloss:0.50936
# [2]	validation_0-logloss:0.46586
# [3]	validation_0-logloss:0.44376
# [4]	validation_0-logloss:0.42703
# [5]	validation_0-logloss:0.42614
# [6]	validation_0-logloss:0.41455
# [7]	validation_0-logloss:0.40647
# [8]	validation_0-logloss:0.41114
# [9]	validation_0-logloss:0.41200
# [10]	validation_0-logloss:0.41270
# [11]	validation_0-logloss:0.41208
# [12]	validation_0-logloss:0.41685
# [13]	validation_0-logloss:0.41901
# [14]	validation_0-logloss:0.42033
# [15]	validation_0-logloss:0.41707
# [16]	validation_0-logloss:0.41855
# [17]	validation_0-logloss:0.42303
# [18]	validation_0-logloss:0.42032
# [19]	validation_0-logloss:0.41882
# [20]	validation_0-logloss:0.42378
# [21]	validation_0-logloss:0.42646
# [22]	validation_0-logloss:0.42578
# [23]	validation_0-logloss:0.42554
# [24]	validation_0-logloss:0.42998
# [25]	validation_0-logloss:0.43024
# [26]	validation_0-logloss:0.43246
# [27]	validation_0-logloss:0.43529
# [28]	validation_0-logloss:0.43710
# [29]	validation_0-logloss:0.43735
# [30]	validation_0-logloss:0.44372
# [31]	validation_0-logloss:0.44492
# [32]	validation_0-logloss:0.44742
# [33]	validation_0-logloss:0.45275
# [0]	validation_0-logloss:0.56894
# [1]	validation_0-logloss:0.50747
# [2]	validation_0-logloss:0.45552
# [3]	validation_0-logloss:0.42813
# [4]	validation_0-logloss:0.40305
# [5]	validation_0-logloss:0.38961
# [6]	validation_0-logloss:0.38352
# [7]	validation_0-logloss:0.38179
# [8]	validation_0-logloss:0.37444
# [9]	validation_0-logloss:0.37593
# [10]	validation_0-logloss:0.37860
# [11]	validation_0-logloss:0.38306
# [12]	validation_0-logloss:0.38445
# [13]	validation_0-logloss:0.38459
# [14]	validation_0-logloss:0.38900
# [15]	validation_0-logloss:0.39076
# [16]	validation_0-logloss:0.39350
# [17]	validation_0-logloss:0.39360
# [18]	validation_0-logloss:0.39675
# [19]	validation_0-logloss:0.39579
# [20]	validation_0-logloss:0.39526
# [21]	validation_0-logloss:0.39951
# [22]	validation_0-logloss:0.40751
# [23]	validation_0-logloss:0.41265
# [24]	validation_0-logloss:0.41077
# [25]	validation_0-logloss:0.41252
# [26]	validation_0-logloss:0.41757
# [27]	validation_0-logloss:0.41942
# [28]	validation_0-logloss:0.42238
# [29]	validation_0-logloss:0.42575
# [30]	validation_0-logloss:0.42975
# [31]	validation_0-logloss:0.42840
# [32]	validation_0-logloss:0.43065
# [33]	validation_0-logloss:0.43355
# [0]	validation_0-logloss:0.58526
# [1]	validation_0-logloss:0.51725
# [2]	validation_0-logloss:0.47618
# [3]	validation_0-logloss:0.45071
# [4]	validation_0-logloss:0.43297
# [5]	validation_0-logloss:0.41933
# [6]	validation_0-logloss:0.40875
# [7]	validation_0-logloss:0.39691
# [8]	validation_0-logloss:0.39380
# [9]	validation_0-logloss:0.39200
# [10]	validation_0-logloss:0.39033
# [11]	validation_0-logloss:0.38783
# [12]	validation_0-logloss:0.38826
# [13]	validation_0-logloss:0.39091
# [14]	validation_0-logloss:0.39662
# [15]	validation_0-logloss:0.40065
# [16]	validation_0-logloss:0.40145
# [17]	validation_0-logloss:0.40405
# [18]	validation_0-logloss:0.40123
# [19]	validation_0-logloss:0.40679
# [20]	validation_0-logloss:0.40713
# [21]	validation_0-logloss:0.41059
# [22]	validation_0-logloss:0.41635
# [23]	validation_0-logloss:0.41753
# [24]	validation_0-logloss:0.42169
# [25]	validation_0-logloss:0.42256
# [26]	validation_0-logloss:0.42831
# [27]	validation_0-logloss:0.42848
# [28]	validation_0-logloss:0.42343
# [29]	validation_0-logloss:0.42538
# [30]	validation_0-logloss:0.42869
# [31]	validation_0-logloss:0.43096
# [32]	validation_0-logloss:0.43197
# [33]	validation_0-logloss:0.43460
# [0]	validation_0-logloss:0.58044
# [1]	validation_0-logloss:0.51224
# [2]	validation_0-logloss:0.46854
# [3]	validation_0-logloss:0.44765
# [4]	validation_0-logloss:0.42899
# [5]	validation_0-logloss:0.42761
# [6]	validation_0-logloss:0.41223
# [7]	validation_0-logloss:0.40549
# [8]	validation_0-logloss:0.40778
# [9]	validation_0-logloss:0.40326
# [10]	validation_0-logloss:0.40510
# [11]	validation_0-logloss:0.40829
# [12]	validation_0-logloss:0.40398
# [13]	validation_0-logloss:0.40794
# [14]	validation_0-logloss:0.40267
# [15]	validation_0-logloss:0.40705
# [16]	validation_0-logloss:0.40426
# [17]	validation_0-logloss:0.40251
# [18]	validation_0-logloss:0.40136
# [19]	validation_0-logloss:0.39826
# [20]	validation_0-logloss:0.40213
# [21]	validation_0-logloss:0.40592
# [22]	validation_0-logloss:0.40675
# [23]	validation_0-logloss:0.40505
# [24]	validation_0-logloss:0.40683
# [25]	validation_0-logloss:0.40616
# [26]	validation_0-logloss:0.40949
# [27]	validation_0-logloss:0.41598
# [28]	validation_0-logloss:0.41958
# [29]	validation_0-logloss:0.42138
# [30]	validation_0-logloss:0.42124
# [31]	validation_0-logloss:0.42553
# [32]	validation_0-logloss:0.42577
# [33]	validation_0-logloss:0.42758
# [0]	validation_0-logloss:0.57161
# [1]	validation_0-logloss:0.51047
# [2]	validation_0-logloss:0.45859
# [3]	validation_0-logloss:0.42623
# [4]	validation_0-logloss:0.40607
# [5]	validation_0-logloss:0.39659
# [6]	validation_0-logloss:0.38268
# [7]	validation_0-logloss:0.37515
# [8]	validation_0-logloss:0.36561
# [9]	validation_0-logloss:0.36608
# [10]	validation_0-logloss:0.36608
# [11]	validation_0-logloss:0.36925
# [12]	validation_0-logloss:0.36855
# [13]	validation_0-logloss:0.37083
# [14]	validation_0-logloss:0.37359
# [15]	validation_0-logloss:0.37894
# [16]	validation_0-logloss:0.37987
# [17]	validation_0-logloss:0.38157
# [18]	validation_0-logloss:0.38541
# [19]	validation_0-logloss:0.38756
# [20]	validation_0-logloss:0.38982
# [21]	validation_0-logloss:0.39084
# [22]	validation_0-logloss:0.39284
# [23]	validation_0-logloss:0.39720
# [24]	validation_0-logloss:0.40452
# [25]	validation_0-logloss:0.40427
# [26]	validation_0-logloss:0.40609
# [27]	validation_0-logloss:0.40882
# [28]	validation_0-logloss:0.41431
# [29]	validation_0-logloss:0.41886
# [30]	validation_0-logloss:0.42031
# [31]	validation_0-logloss:0.42345
# [32]	validation_0-logloss:0.42398
# [33]	validation_0-logloss:0.42300
# [0]	validation_0-logloss:0.58749
# [1]	validation_0-logloss:0.51999
# [2]	validation_0-logloss:0.47852
# [3]	validation_0-logloss:0.45257
# [4]	validation_0-logloss:0.43458
# [5]	validation_0-logloss:0.41731
# [6]	validation_0-logloss:0.40775
# [7]	validation_0-logloss:0.40088
# [8]	validation_0-logloss:0.39909
# [9]	validation_0-logloss:0.39678
# [10]	validation_0-logloss:0.40140
# [11]	validation_0-logloss:0.39897
# [12]	validation_0-logloss:0.40146
# [13]	validation_0-logloss:0.39829
# [14]	validation_0-logloss:0.40075
# [15]	validation_0-logloss:0.40101
# [16]	validation_0-logloss:0.40210
# [17]	validation_0-logloss:0.40174
# [18]	validation_0-logloss:0.39829
# [19]	validation_0-logloss:0.40259
# [20]	validation_0-logloss:0.40689
# [21]	validation_0-logloss:0.41269
# [22]	validation_0-logloss:0.41561
# [23]	validation_0-logloss:0.41640
# [24]	validation_0-logloss:0.41703
# [25]	validation_0-logloss:0.41943
# [26]	validation_0-logloss:0.41889
# [27]	validation_0-logloss:0.42041
# [28]	validation_0-logloss:0.41802
# [29]	validation_0-logloss:0.41877
# [30]	validation_0-logloss:0.42033
# [31]	validation_0-logloss:0.41825
# [32]	validation_0-logloss:0.42471
# [33]	validation_0-logloss:0.42596
# [0]	validation_0-logloss:0.58320
# [1]	validation_0-logloss:0.51779
# [2]	validation_0-logloss:0.48151
# [3]	validation_0-logloss:0.44995
# [4]	validation_0-logloss:0.43221
# [5]	validation_0-logloss:0.41738
# [6]	validation_0-logloss:0.40934
# [7]	validation_0-logloss:0.40143
# [8]	validation_0-logloss:0.39374
# [9]	validation_0-logloss:0.38901
# [10]	validation_0-logloss:0.38157
# [11]	validation_0-logloss:0.37758
# [12]	validation_0-logloss:0.37598
# [13]	validation_0-logloss:0.37337
# [14]	validation_0-logloss:0.37304
# [15]	validation_0-logloss:0.37781
# [16]	validation_0-logloss:0.38058
# [17]	validation_0-logloss:0.37769
# [18]	validation_0-logloss:0.37854
# [19]	validation_0-logloss:0.37850
# [20]	validation_0-logloss:0.37691
# [21]	validation_0-logloss:0.37942
# [22]	validation_0-logloss:0.38197
# [23]	validation_0-logloss:0.38554
# [24]	validation_0-logloss:0.39192
# [25]	validation_0-logloss:0.39409
# [26]	validation_0-logloss:0.39754
# [27]	validation_0-logloss:0.39679
# [28]	validation_0-logloss:0.39959
# [29]	validation_0-logloss:0.40046
# [30]	validation_0-logloss:0.40003
# [31]	validation_0-logloss:0.40224
# [32]	validation_0-logloss:0.40269
# [33]	validation_0-logloss:0.40384
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            callbacks=None, colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1,
#                                            early_stopping_rounds=50,
#                                            enable_categorical=False,
#                                            eval_metric='logloss', gamma=0,
#                                            gpu_id=-1, grow_policy='depthwise',
#                                            importance_type=None,
#                                            interaction_constraints='',
#                                            learning_rate=0.1, max_bin=256,
#                                            max_c...
#                                            max_delta_step=0, max_depth=6,
#                                            max_leaves=0, min_child_weight=1,
#                                            missing=nan,
#                                            monotone_constraints='()',
#                                            n_estimators=34, n_jobs=0,
#                                            num_parallel_tree=1,
#                                            predictor='auto', random_state=808,
#                                            reg_alpha=0, reg_lambda=1, ...),
#                    n_iter=20,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f5bf614db90>},
#                    random_state=808, scoring='accuracy', verbose=False)

# %%
# Print best number of learners
best_lr = rs.best_params_['learning_rate']
print(f"Best learning rate: {best_lr:.4f}")
# Out:
# Best learning rate: 0.2320

# %% [markdown]
# ### Step 4: Tune Tree-Specific Parameters
#
# Now that we've determined the best number of tree and learning rate, we need to tune the complexity of individual trees in our model. Initialize your model with the best number of trees and learning rate.Then, define a parameter dictionary that takes on the following values:
#
# - `max_depth`(Controls how deep each tree can grow.  Takes integer values): A random integer from 3 to 10 ( inclusive of 3 and 10)
# - `min_child_weight`( Determines the minimum number of samples required in a leaf node. Takes integer values) : A random integer from 1 to 10 ( inclusive of 1 and 10)
# - `gamma` (Defines the minimum loss reduction needed to make a further split in a tree. Can take on values from a continuous range):  A uniform distribution from 0.05 to 0.10 - once again remember to check the `scipy.stats.uniform()` documentation!
# - `random_state = 808`
#
# To find the best combination, we again use `RandomizedSearchCV`, allowing us to efficiently sample hyperparameters and evaluate different configurations using cross-validation. After fitting the model, print the best parameters.

# %%
# Initialize third XGB model
xgb3 = XGBClassifier(
    n_estimators=best_ntrees,
    learning_rate=0.1, 
    early_stopping_rounds=50, 
    eval_metric="logloss", 
    random_state=808)

# Fit model
xgb2.fit(X_train, y_train, eval_set=[(X_val, y_val)])

# Create a parameter distribution for learning rate
param_dist = {
    "learning_rate": uniform(0.01, 0.3), 
}

# Set up RandomizedSearchCV
rs = RandomizedSearchCV(
    xgb2, param_dist, n_iter=20, scoring='accuracy', 
    cv=3, verbose=False, random_state=808
)

# Run random search
rs.fit(X_train, y_train, eval_set=[(X_val, y_val)])

# %% [markdown]
# ### Step 5: Tune Stochastic Components
#
# Now, we are finally ready to tune the stochastic components of the XGBoost model.  These parameters help prevent overfitting by reducing correlation between trees. Initialize your model with the best number of trees, best learning rate,and your optimized tree values (**Note**: you can use \**best_tree_parameters to unpack the the dictionary of optimzed tree values) .Then, define a parameter dictionary that takes on the following values:
#
# - `subsample` (Controls the fraction of training samples used for each boosting round) : A uniform distribution between .5 and .10 (remeber to check `scipy.stats.uniform()` documentation! )
# - `colsample_bytree`(Specifies the fraction of features to consider when building each tree) : A uniform distribution between .5 and .10
# - `random_state = 808`
#
# We again use `RandomizedSearchCV` to find the best combination of these parameters. After fitting the model, print the best parameters.

# %% [markdown]
# ### Step 6: Final Model Training and Evaluation
#
# With the best hyperparameters selected, we now train the final model on the full training dataset and evaluate it on the separate evaluation dataset.
#
# 1. Prepare the evaluation data in the same manner as you did the training data
#
# 2. Train final model using the best parameters found in previous tuning steps (`best_tree_params`, `best_stochastic_params`).Set  `eval_metric = "logloss"`
#
# 3. Fit the model to the full training dataset and predict on the evaluation data

# %% [markdown]
# ### Step 7: Model Performance
#
# Compute and print the AUC and feature importances for your model.

# %% [markdown]
# ### Step 8: The comparison
# How does your model's performance compare to the of Elith et al. (See Tables 2 and 3)?  Is there another way to compare the models in addition to predictive performance?  Whose model wins in that regard?

# %% [markdown]
# *Your answer here*
